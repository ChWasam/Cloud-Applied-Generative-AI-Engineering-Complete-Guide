# %%
import requests

from requests.models import Response
from requests.structures import CaseInsensitiveDict

response : Response = requests.get('https://simple-books-api.glitch.me')

# When you make an HTTP request to a server, the response might be in various formats such as HTML, plain text, XML, or JSON. If the response is in JSON format, it means the data is structured as a series of key-value pairs, similar to a Python dictionary.

print(response)
print(response.status_code)

headers : CaseInsensitiveDict = response.headers
print(headers)

# display(response.text) will convert response to json string 
display(response.text)
#  response.text => str type ha

import json 
data = json.loads(response.text)
print(data)


print(response.content)
# Unlike response.text, which attempts to decode the content using the encoding specified in the response headers (defaulting to utf-8 if none is provided), response.content does not decode the content and returns it as-is.

display(response.json())
#  yeh command basically json ko parse karti ha 
# response.json() converts the response content to a Python dictionary (or list) only if the response is in JSON format. If the response is not in JSON format, you’ll get a ValueError: No JSON object could be decoded.

# It is good practice to check the Content-Type header or use a try-except block to handle cases where the response might not be JSON.
print(response.headers['Content-Type'])

#  When json = {"message":"Welcome to the Simple Books API."} converted to dictionary it turn into single quote json = {'message': 'Welcome to the Simple Books API.'}



# samjho yeh response ay ha server sa {"message":"Welcome to the Simple Books API."}
# hama message access server sa access karna ha to response.mmessage ho ga 
# agar json string me convert kis to asa direct access nahi kar saktay
#  is ka lia display(response.json()) use karna hota ha
# phir hama dictionary ka tariqa sa access karna hota ha like response.json()['message']

print(response.json()['message'])


#   we can also use  type() to Check the Data Type of the Response
# Out:
# <Response [200]>
# 200
# {'Date': 'Tue, 30 Jul 2024 08:00:26 GMT', 'Content-Type': 'application/json; charset=utf-8', 'Content-Length': '46', 'Connection': 'keep-alive', 'x-powered-by': 'Express', 'etag': 'W/"2e-kh6L/Eo2ZbYePMROtHK7TuPdR1U"'}
# '{"message":"Welcome to the Simple Books API."}'
# {'message': 'Welcome to the Simple Books API.'}
# b'{"message":"Welcome to the Simple Books API."}'
# {'message': 'Welcome to the Simple Books API.'}
# application/json; charset=utf-8
# Welcome to the Simple Books API.

# %%
import requests

import requests.models as Response
import requests.structures as CaseInsensitiveDict

response : Response = requests.get('https://www.dawn.com/news/1848918/no-country-for-women')

print(response)

print(response.text)
# Out:
# <Response [200]>
# <!DOCTYPE html>
# <html lang="en">
#
# <head>
#
#     <!-- meta -->
#     <meta charset="utf-8">
#     <meta name="viewport" content="width=device-width,minimum-scale=1,initial-scale=1">
#     <!--[if IE]> <meta http-equiv="X-UA-Compatible" content="IE=edge" /> <![endif]-->
#     <title>No country for women - Newspaper - DAWN.COM</title>
#      <meta name='subject' content='Your window to latest news, analysis and features from Pakistan, South Asia and the world.' />
#      <meta name='description' content='After all, this is a state and society which has never been comfortable with women who want to take their fate into their own hands.' />
#      <meta property='fb:app_id' content='1383068068604634' />
#      <meta property='og:locale' content='en_US' />
#      <link rel='canonical' href='https://www.dawn.com/news/1848918' />
#      <link rel='amphtml' href='https://www.dawn.com/news/amp/1848918' />
# ...

# %% [markdown]
# # POST Method
#
# ### Koi bhi information ap secure way me bhajta han

# %% [markdown]
# ## User authentication

# %%
data = {
    "clientName": "qqbbllq786",
   "clientEmail": "qqbbllq786@example.com"
}

response : Response = requests.post('https://simple-books-api.glitch.me/api-clients/', json =data)

print(response.text)
# Out:
# {"accessToken":"0dd72bba74131789c8e6d304a84141aecf090d85f97893dd56c4aeb66ab02866"}

# %% [markdown]
# ## Submit an order

# %%
headers = {"Authorization": "Bearer 0dd72bba74131789c8e6d304a84141aecf090d85f97893dd56c4aeb66ab02866"}

data = {
"bookId": 3,
"customerName": "Wasam"
}
response : Response = requests.post('https://simple-books-api.glitch.me//orders', headers=headers  ,json =data)

print(response.text)
# Out:
# {"created":true,"orderId":"3zaQkB45mwv35DlmbSI8M"}

# %% [markdown]
# ## Get an order

# %%
headers = {"Authorization": "Bearer 0dd72bba74131789c8e6d304a84141aecf090d85f97893dd56c4aeb66ab02866"}
orderId = "3zaQkB45mwv35DlmbSI8M"
data = {
"bookId": 3,
"customerName": "wasam"
}
response : Response = requests.get(f'https://simple-books-api.glitch.me//orders/{orderId}', headers=headers)

print(response.text)
# Out:
# {"error":"No order with id 3zaQkB45mwv35DlmbSI8M."}

# %% [markdown]
# ## Update an order

# %%
headers = {"Authorization": "Bearer 0dd72bba74131789c8e6d304a84141aecf090d85f97893dd56c4aeb66ab02866"}
orderId = "3zaQkB45mwv35DlmbSI8M"
data = {
"customerName": "Rehman"
}
response : Response = requests.patch(f'https://simple-books-api.glitch.me//orders/{orderId}', headers=headers  ,json =data)

print(response.status_code)
# Out:
# 204

# %% [markdown]
# ## Delete an order

# %%
headers = {"Authorization": "Bearer 0dd72bba74131789c8e6d304a84141aecf090d85f97893dd56c4aeb66ab02866"}
orderId = "3zaQkB45mwv35DlmbSI8M"

response : Response = requests.delete(f'https://simple-books-api.glitch.me//orders/{orderId}', headers=headers)

print(response.status_code)
# Out:
# 204

# %% [markdown]
# # Understanding json in more depth

# %% [markdown]
# ## In the context of the requests library, response.json() is used to parse a JSON response from an HTTP request into a Python dictionary.

# %%
import requests

response = requests.get('https://api.example.com/data')
data = response.json()  # Converts JSON response to a Python dictionary

# %% [markdown]
# ## In the context of Pydantic, user1.json() is used to convert a Pydantic model instance to a JSON string

# %%
# user1_json = user1.json()  # Converts User object to a JSON string
