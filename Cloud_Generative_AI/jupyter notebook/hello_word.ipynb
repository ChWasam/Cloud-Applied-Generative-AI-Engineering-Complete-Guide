# %%
print("Wasam")
# Out:
# Wasam

# %% [markdown]
# # ***Learning Jupyter notebook***
#
# * Jupyter *notebook*

# %%
! pip3 install pandas matplotlib
# Out:
# Requirement already satisfied: pandas in /opt/anaconda3/envs/py312/lib/python3.12/site-packages (2.2.2)
# Requirement already satisfied: matplotlib in /opt/anaconda3/envs/py312/lib/python3.12/site-packages (3.9.2)
# Requirement already satisfied: numpy>=1.26.0 in /opt/anaconda3/envs/py312/lib/python3.12/site-packages (from pandas) (2.1.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/anaconda3/envs/py312/lib/python3.12/site-packages (from pandas) (2.9.0)
# Requirement already satisfied: pytz>=2020.1 in /opt/anaconda3/envs/py312/lib/python3.12/site-packages (from pandas) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /opt/anaconda3/envs/py312/lib/python3.12/site-packages (from pandas) (2024.1)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/anaconda3/envs/py312/lib/python3.12/site-packages (from matplotlib) (1.3.0)
# Requirement already satisfied: cycler>=0.10 in /opt/anaconda3/envs/py312/lib/python3.12/site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/anaconda3/envs/py312/lib/python3.12/site-packages (from matplotlib) (4.53.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /opt/anaconda3/envs/py312/lib/python3.12/site-packages (from matplotlib) (1.4.7)
# Requirement already satisfied: packaging>=20.0 in /opt/anaconda3/envs/py312/lib/python3.12/site-packages (from matplotlib) (24.0)
# Requirement already satisfied: pillow>=8 in /opt/anaconda3/envs/py312/lib/python3.12/site-packages (from matplotlib) (10.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /opt/anaconda3/envs/py312/lib/python3.12/site-packages (from matplotlib) (3.1.4)
# Requirement already satisfied: six>=1.5 in /opt/anaconda3/envs/py312/lib/python3.12/site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)

# %%
import pandas as pd

# Load a dataset (for example, an inbuilt dataset)
data = pd.read_csv('https://raw.githubusercontent.com/mwaskom/seaborn-data/master/iris.csv')

# Display the first few rows of the dataset
data.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
import matplotlib.pyplot as plt

# Create a simple scatter plot
plt.figure(figsize=(8, 6))
plt.scatter(data['sepal_length'], data['sepal_width'])
plt.title('Sepal Length vs Sepal Width')
plt.xlabel('Sepal Length')
plt.ylabel('Sepal Width')
plt.show()

# %%
# %matplotlib inline

# %%
sum(range(1000))
# Out:
# 499500

# %%
# %timeit sum(range(1000))
# Out:
# 10 µs ± 28.3 ns per loop (mean ± std. dev. of 7 runs, 100,000 loops each)

# %%
# %time
sum(range(1000))
print("Done")
# Out:
# CPU times: user 2 µs, sys: 0 ns, total: 2 µs
# Wall time: 4.77 µs
# Done

# %%
pip install ipywidgets
# Out:
# Requirement already satisfied: ipywidgets in /opt/anaconda3/envs/py312/lib/python3.12/site-packages (8.1.5)
# Requirement already satisfied: comm>=0.1.3 in /opt/anaconda3/envs/py312/lib/python3.12/site-packages (from ipywidgets) (0.2.2)
# Requirement already satisfied: ipython>=6.1.0 in /opt/anaconda3/envs/py312/lib/python3.12/site-packages (from ipywidgets) (8.22.2)
# Requirement already satisfied: traitlets>=4.3.1 in /opt/anaconda3/envs/py312/lib/python3.12/site-packages (from ipywidgets) (5.14.2)
# Requirement already satisfied: widgetsnbextension~=4.0.12 in /opt/anaconda3/envs/py312/lib/python3.12/site-packages (from ipywidgets) (4.0.13)
# Requirement already satisfied: jupyterlab-widgets~=3.0.12 in /opt/anaconda3/envs/py312/lib/python3.12/site-packages (from ipywidgets) (3.0.13)
# Requirement already satisfied: decorator in /opt/anaconda3/envs/py312/lib/python3.12/site-packages (from ipython>=6.1.0->ipywidgets) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in /opt/anaconda3/envs/py312/lib/python3.12/site-packages (from ipython>=6.1.0->ipywidgets) (0.19.1)
# Requirement already satisfied: matplotlib-inline in /opt/anaconda3/envs/py312/lib/python3.12/site-packages (from ipython>=6.1.0->ipywidgets) (0.1.6)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.41 in /opt/anaconda3/envs/py312/lib/python3.12/site-packages (from ipython>=6.1.0->ipywidgets) (3.0.42)
# Requirement already satisfied: pygments>=2.4.0 in /opt/anaconda3/envs/py312/lib/python3.12/site-packages (from ipython>=6.1.0->ipywidgets) (2.17.2)
# Requirement already satisfied: stack-data in /opt/anaconda3/envs/py312/lib/python3.12/site-packages (from ipython>=6.1.0->ipywidgets) (0.6.2)
# Requirement already satisfied: pexpect>4.3 in /opt/anaconda3/envs/py312/lib/python3.12/site-packages (from ipython>=6.1.0->ipywidgets) (4.9.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in /opt/anaconda3/envs/py312/lib/python3.12/site-packages (from jedi>=0.16->ipython>=6.1.0->ipywidgets) (0.8.3)
# Requirement already satisfied: ptyprocess>=0.5 in /opt/anaconda3/envs/py312/lib/python3.12/site-packages (from pexpect>4.3->ipython>=6.1.0->ipywidgets) (0.7.0)
# Requirement already satisfied: wcwidth in /opt/anaconda3/envs/py312/lib/python3.12/site-packages (from prompt-toolkit<3.1.0,>=3.0.41->ipython>=6.1.0->ipywidgets) (0.2.13)
# Requirement already satisfied: executing>=1.2.0 in /opt/anaconda3/envs/py312/lib/python3.12/site-packages (from stack-data->ipython>=6.1.0->ipywidgets) (2.0.1)
# Requirement already satisfied: asttokens>=2.1.0 in /opt/anaconda3/envs/py312/lib/python3.12/site-packages (from stack-data->ipython>=6.1.0->ipywidgets) (2.4.1)
# Requirement already satisfied: pure-eval in /opt/anaconda3/envs/py312/lib/python3.12/site-packages (from stack-data->ipython>=6.1.0->ipywidgets) (0.2.2)
# Requirement already satisfied: six>=1.12.0 in /opt/anaconda3/envs/py312/lib/python3.12/site-packages (from asttokens>=2.1.0->stack-data->ipython>=6.1.0->ipywidgets) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import ipywidgets as widgets
from IPython.display import display

slider = widgets.IntSlider(min=0, max=10, value=5)
display(slider)
# Out:
# IntSlider(value=5, max=10)

# %%
# !pip uninstall -y jupyter-contrib-nbextensions
# Out:
# Found existing installation: jupyter-contrib-nbextensions 0.7.0
# Uninstalling jupyter-contrib-nbextensions-0.7.0:
#   Successfully uninstalled jupyter-contrib-nbextensions-0.7.0

# %%
! pip install jupyter-contrib-nbextensions
# Out:
# Collecting jupyter-contrib-nbextensions
#   Using cached jupyter_contrib_nbextensions-0.7.0-py2.py3-none-any.whl
# Requirement already satisfied: ipython-genutils in /opt/anaconda3/envs/py312/lib/python3.12/site-packages (from jupyter-contrib-nbextensions) (0.2.0)
# Requirement already satisfied: jupyter-contrib-core>=0.3.3 in /opt/anaconda3/envs/py312/lib/python3.12/site-packages (from jupyter-contrib-nbextensions) (0.4.2)
# Requirement already satisfied: jupyter-core in /opt/anaconda3/envs/py312/lib/python3.12/site-packages (from jupyter-contrib-nbextensions) (5.5.0)
# Requirement already satisfied: jupyter-highlight-selected-word>=0.1.1 in /opt/anaconda3/envs/py312/lib/python3.12/site-packages (from jupyter-contrib-nbextensions) (0.2.0)
# Requirement already satisfied: jupyter-nbextensions-configurator>=0.4.0 in /opt/anaconda3/envs/py312/lib/python3.12/site-packages (from jupyter-contrib-nbextensions) (0.6.4)
# Requirement already satisfied: nbconvert>=6.0 in /opt/anaconda3/envs/py312/lib/python3.12/site-packages (from jupyter-contrib-nbextensions) (7.16.4)
# Requirement already satisfied: notebook>=6.0 in /opt/anaconda3/envs/py312/lib/python3.12/site-packages (from jupyter-contrib-nbextensions) (7.2.2)
# Requirement already satisfied: tornado in /opt/anaconda3/envs/py312/lib/python3.12/site-packages (from jupyter-contrib-nbextensions) (6.3.3)
# Requirement already satisfied: traitlets>=4.1 in /opt/anaconda3/envs/py312/lib/python3.12/site-packages (from jupyter-contrib-nbextensions) (5.14.2)
# Requirement already satisfied: lxml in /opt/anaconda3/envs/py312/lib/python3.12/site-packages (from jupyter-contrib-nbextensions) (5.3.0)
# Requirement already satisfied: setuptools in /opt/anaconda3/envs/py312/lib/python3.12/site-packages (from jupyter-contrib-core>=0.3.3->jupyter-contrib-nbextensions) (68.2.2)
# Requirement already satisfied: jupyter-server in /opt/anaconda3/envs/py312/lib/python3.12/site-packages (from jupyter-nbextensions-configurator>=0.4.0->jupyter-contrib-nbextensions) (2.14.2)
# Requirement already satisfied: pyyaml in /opt/anaconda3/envs/py312/lib/python3.12/site-packages (from jupyter-nbextensions-configurator>=0.4.0->jupyter-contrib-nbextensions) (6.0.2)
# Requirement already satisfied: beautifulsoup4 in /opt/anaconda3/envs/py312/lib/python3.12/site-packages (from nbconvert>=6.0->jupyter-contrib-nbextensions) (4.12.3)
# Requirement already satisfied: bleach!=5.0.0 in /opt/anaconda3/envs/py312/lib/python3.12/site-packages (from nbconvert>=6.0->jupyter-contrib-nbextensions) (6.1.0)
# Requirement already satisfied: defusedxml in /opt/anaconda3/envs/py312/lib/python3.12/site-packages (from nbconvert>=6.0->jupyter-contrib-nbextensions) (0.7.1)
# Requirement already satisfied: jinja2>=3.0 in /opt/anaconda3/envs/py312/lib/python3.12/site-packages (from nbconvert>=6.0->jupyter-contrib-nbextensions) (3.1.4)
# Requirement already satisfied: jupyterlab-pygments in /opt/anaconda3/envs/py312/lib/python3.12/site-packages (from nbconvert>=6.0->jupyter-contrib-nbextensions) (0.3.0)
# Requirement already satisfied: markupsafe>=2.0 in /opt/anaconda3/envs/py312/lib/python3.12/site-packages (from nbconvert>=6.0->jupyter-contrib-nbextensions) (2.1.5)
# Requirement already satisfied: mistune<4,>=2.0.3 in /opt/anaconda3/envs/py312/lib/python3.12/site-packages (from nbconvert>=6.0->jupyter-contrib-nbextensions) (3.0.2)
# Requirement already satisfied: nbclient>=0.5.0 in /opt/anaconda3/envs/py312/lib/python3.12/site-packages (from nbconvert>=6.0->jupyter-contrib-nbextensions) (0.10.0)
# Requirement already satisfied: nbformat>=5.7 in /opt/anaconda3/envs/py312/lib/python3.12/site-packages (from nbconvert>=6.0->jupyter-contrib-nbextensions) (5.10.4)
# Requirement already satisfied: packaging in /opt/anaconda3/envs/py312/lib/python3.12/site-packages (from nbconvert>=6.0->jupyter-contrib-nbextensions) (24.0)
# Requirement already satisfied: pandocfilters>=1.4.1 in /opt/anaconda3/envs/py312/lib/python3.12/site-packages (from nbconvert>=6.0->jupyter-contrib-nbextensions) (1.5.1)
# Requirement already satisfied: pygments>=2.4.1 in /opt/anaconda3/envs/py312/lib/python3.12/site-packages (from nbconvert>=6.0->jupyter-contrib-nbextensions) (2.17.2)
# Requirement already satisfied: tinycss2 in /opt/anaconda3/envs/py312/lib/python3.12/site-packages (from nbconvert>=6.0->jupyter-contrib-nbextensions) (1.3.0)
# Requirement already satisfied: platformdirs>=2.5 in /opt/anaconda3/envs/py312/lib/python3.12/site-packages (from jupyter-core->jupyter-contrib-nbextensions) (4.2.0)
# Requirement already satisfied: jupyterlab-server<3,>=2.27.1 in /opt/anaconda3/envs/py312/lib/python3.12/site-packages (from notebook>=6.0->jupyter-contrib-nbextensions) (2.27.3)
# Requirement already satisfied: jupyterlab<4.3,>=4.2.0 in /opt/anaconda3/envs/py312/lib/python3.12/site-packages (from notebook>=6.0->jupyter-contrib-nbextensions) (4.2.5)
# Requirement already satisfied: notebook-shim<0.3,>=0.2 in /opt/anaconda3/envs/py312/lib/python3.12/site-packages (from notebook>=6.0->jupyter-contrib-nbextensions) (0.2.4)
# Requirement already satisfied: six>=1.9.0 in /opt/anaconda3/envs/py312/lib/python3.12/site-packages (from bleach!=5.0.0->nbconvert>=6.0->jupyter-contrib-nbextensions) (1.16.0)
# Requirement already satisfied: webencodings in /opt/anaconda3/envs/py312/lib/python3.12/site-packages (from bleach!=5.0.0->nbconvert>=6.0->jupyter-contrib-nbextensions) (0.5.1)
# Requirement already satisfied: anyio>=3.1.0 in /opt/anaconda3/envs/py312/lib/python3.12/site-packages (from jupyter-server->jupyter-nbextensions-configurator>=0.4.0->jupyter-contrib-nbextensions) (4.4.0)
# Requirement already satisfied: argon2-cffi>=21.1 in /opt/anaconda3/envs/py312/lib/python3.12/site-packages (from jupyter-server->jupyter-nbextensions-configurator>=0.4.0->jupyter-contrib-nbextensions) (23.1.0)
# Requirement already satisfied: jupyter-client>=7.4.4 in /opt/anaconda3/envs/py312/lib/python3.12/site-packages (from jupyter-server->jupyter-nbextensions-configurator>=0.4.0->jupyter-contrib-nbextensions) (8.6.1)
# Requirement already satisfied: jupyter-events>=0.9.0 in /opt/anaconda3/envs/py312/lib/python3.12/site-packages (from jupyter-server->jupyter-nbextensions-configurator>=0.4.0->jupyter-contrib-nbextensions) (0.10.0)
# Requirement already satisfied: jupyter-server-terminals>=0.4.4 in /opt/anaconda3/envs/py312/lib/python3.12/site-packages (from jupyter-server->jupyter-nbextensions-configurator>=0.4.0->jupyter-contrib-nbextensions) (0.5.3)
# Requirement already satisfied: overrides>=5.0 in /opt/anaconda3/envs/py312/lib/python3.12/site-packages (from jupyter-server->jupyter-nbextensions-configurator>=0.4.0->jupyter-contrib-nbextensions) (7.7.0)
# Requirement already satisfied: prometheus-client>=0.9 in /opt/anaconda3/envs/py312/lib/python3.12/site-packages (from jupyter-server->jupyter-nbextensions-configurator>=0.4.0->jupyter-contrib-nbextensions) (0.20.0)
# Requirement already satisfied: pyzmq>=24 in /opt/anaconda3/envs/py312/lib/python3.12/site-packages (from jupyter-server->jupyter-nbextensions-configurator>=0.4.0->jupyter-contrib-nbextensions) (25.1.2)
# Requirement already satisfied: send2trash>=1.8.2 in /opt/anaconda3/envs/py312/lib/python3.12/site-packages (from jupyter-server->jupyter-nbextensions-configurator>=0.4.0->jupyter-contrib-nbextensions) (1.8.3)
# Requirement already satisfied: terminado>=0.8.3 in /opt/anaconda3/envs/py312/lib/python3.12/site-packages (from jupyter-server->jupyter-nbextensions-configurator>=0.4.0->jupyter-contrib-nbextensions) (0.18.1)
# Requirement already satisfied: websocket-client>=1.7 in /opt/anaconda3/envs/py312/lib/python3.12/site-packages (from jupyter-server->jupyter-nbextensions-configurator>=0.4.0->jupyter-contrib-nbextensions) (1.8.0)
# Requirement already satisfied: async-lru>=1.0.0 in /opt/anaconda3/envs/py312/lib/python3.12/site-packages (from jupyterlab<4.3,>=4.2.0->notebook>=6.0->jupyter-contrib-nbextensions) (2.0.4)
# Requirement already satisfied: httpx>=0.25.0 in /opt/anaconda3/envs/py312/lib/python3.12/site-packages (from jupyterlab<4.3,>=4.2.0->notebook>=6.0->jupyter-contrib-nbextensions) (0.27.2)
# Requirement already satisfied: ipykernel>=6.5.0 in /opt/anaconda3/envs/py312/lib/python3.12/site-packages (from jupyterlab<4.3,>=4.2.0->notebook>=6.0->jupyter-contrib-nbextensions) (6.29.3)
# Requirement already satisfied: jupyter-lsp>=2.0.0 in /opt/anaconda3/envs/py312/lib/python3.12/site-packages (from jupyterlab<4.3,>=4.2.0->notebook>=6.0->jupyter-contrib-nbextensions) (2.2.5)
# Requirement already satisfied: babel>=2.10 in /opt/anaconda3/envs/py312/lib/python3.12/site-packages (from jupyterlab-server<3,>=2.27.1->notebook>=6.0->jupyter-contrib-nbextensions) (2.16.0)
# Requirement already satisfied: json5>=0.9.0 in /opt/anaconda3/envs/py312/lib/python3.12/site-packages (from jupyterlab-server<3,>=2.27.1->notebook>=6.0->jupyter-contrib-nbextensions) (0.9.25)
# Requirement already satisfied: jsonschema>=4.18.0 in /opt/anaconda3/envs/py312/lib/python3.12/site-packages (from jupyterlab-server<3,>=2.27.1->notebook>=6.0->jupyter-contrib-nbextensions) (4.23.0)
# Requirement already satisfied: requests>=2.31 in /opt/anaconda3/envs/py312/lib/python3.12/site-packages (from jupyterlab-server<3,>=2.27.1->notebook>=6.0->jupyter-contrib-nbextensions) (2.31.0)
# Requirement already satisfied: fastjsonschema>=2.15 in /opt/anaconda3/envs/py312/lib/python3.12/site-packages (from nbformat>=5.7->nbconvert>=6.0->jupyter-contrib-nbextensions) (2.20.0)
# Requirement already satisfied: soupsieve>1.2 in /opt/anaconda3/envs/py312/lib/python3.12/site-packages (from beautifulsoup4->nbconvert>=6.0->jupyter-contrib-nbextensions) (2.6)
# Requirement already satisfied: idna>=2.8 in /opt/anaconda3/envs/py312/lib/python3.12/site-packages (from anyio>=3.1.0->jupyter-server->jupyter-nbextensions-configurator>=0.4.0->jupyter-contrib-nbextensions) (3.4)
# Requirement already satisfied: sniffio>=1.1 in /opt/anaconda3/envs/py312/lib/python3.12/site-packages (from anyio>=3.1.0->jupyter-server->jupyter-nbextensions-configurator>=0.4.0->jupyter-contrib-nbextensions) (1.3.1)
# Requirement already satisfied: argon2-cffi-bindings in /opt/anaconda3/envs/py312/lib/python3.12/site-packages (from argon2-cffi>=21.1->jupyter-server->jupyter-nbextensions-configurator>=0.4.0->jupyter-contrib-nbextensions) (21.2.0)
# Requirement already satisfied: certifi in /opt/anaconda3/envs/py312/lib/python3.12/site-packages (from httpx>=0.25.0->jupyterlab<4.3,>=4.2.0->notebook>=6.0->jupyter-contrib-nbextensions) (2024.2.2)
# Requirement already satisfied: httpcore==1.* in /opt/anaconda3/envs/py312/lib/python3.12/site-packages (from httpx>=0.25.0->jupyterlab<4.3,>=4.2.0->notebook>=6.0->jupyter-contrib-nbextensions) (1.0.5)
# Requirement already satisfied: h11<0.15,>=0.13 in /opt/anaconda3/envs/py312/lib/python3.12/site-packages (from httpcore==1.*->httpx>=0.25.0->jupyterlab<4.3,>=4.2.0->notebook>=6.0->jupyter-contrib-nbextensions) (0.14.0)
# Requirement already satisfied: appnope in /opt/anaconda3/envs/py312/lib/python3.12/site-packages (from ipykernel>=6.5.0->jupyterlab<4.3,>=4.2.0->notebook>=6.0->jupyter-contrib-nbextensions) (0.1.4)
# Requirement already satisfied: comm>=0.1.1 in /opt/anaconda3/envs/py312/lib/python3.12/site-packages (from ipykernel>=6.5.0->jupyterlab<4.3,>=4.2.0->notebook>=6.0->jupyter-contrib-nbextensions) (0.2.2)
# Requirement already satisfied: debugpy>=1.6.5 in /opt/anaconda3/envs/py312/lib/python3.12/site-packages (from ipykernel>=6.5.0->jupyterlab<4.3,>=4.2.0->notebook>=6.0->jupyter-contrib-nbextensions) (1.6.7)
# Requirement already satisfied: ipython>=7.23.1 in /opt/anaconda3/envs/py312/lib/python3.12/site-packages (from ipykernel>=6.5.0->jupyterlab<4.3,>=4.2.0->notebook>=6.0->jupyter-contrib-nbextensions) (8.22.2)
# Requirement already satisfied: matplotlib-inline>=0.1 in /opt/anaconda3/envs/py312/lib/python3.12/site-packages (from ipykernel>=6.5.0->jupyterlab<4.3,>=4.2.0->notebook>=6.0->jupyter-contrib-nbextensions) (0.1.6)
# Requirement already satisfied: nest-asyncio in /opt/anaconda3/envs/py312/lib/python3.12/site-packages (from ipykernel>=6.5.0->jupyterlab<4.3,>=4.2.0->notebook>=6.0->jupyter-contrib-nbextensions) (1.6.0)
# Requirement already satisfied: psutil in /opt/anaconda3/envs/py312/lib/python3.12/site-packages (from ipykernel>=6.5.0->jupyterlab<4.3,>=4.2.0->notebook>=6.0->jupyter-contrib-nbextensions) (5.9.0)
# Requirement already satisfied: attrs>=22.2.0 in /opt/anaconda3/envs/py312/lib/python3.12/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->notebook>=6.0->jupyter-contrib-nbextensions) (24.2.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /opt/anaconda3/envs/py312/lib/python3.12/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->notebook>=6.0->jupyter-contrib-nbextensions) (2023.12.1)
# Requirement already satisfied: referencing>=0.28.4 in /opt/anaconda3/envs/py312/lib/python3.12/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->notebook>=6.0->jupyter-contrib-nbextensions) (0.35.1)
# Requirement already satisfied: rpds-py>=0.7.1 in /opt/anaconda3/envs/py312/lib/python3.12/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->notebook>=6.0->jupyter-contrib-nbextensions) (0.20.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/anaconda3/envs/py312/lib/python3.12/site-packages (from jupyter-client>=7.4.4->jupyter-server->jupyter-nbextensions-configurator>=0.4.0->jupyter-contrib-nbextensions) (2.9.0)
# Requirement already satisfied: python-json-logger>=2.0.4 in /opt/anaconda3/envs/py312/lib/python3.12/site-packages (from jupyter-events>=0.9.0->jupyter-server->jupyter-nbextensions-configurator>=0.4.0->jupyter-contrib-nbextensions) (2.0.7)
# Requirement already satisfied: rfc3339-validator in /opt/anaconda3/envs/py312/lib/python3.12/site-packages (from jupyter-events>=0.9.0->jupyter-server->jupyter-nbextensions-configurator>=0.4.0->jupyter-contrib-nbextensions) (0.1.4)
# Requirement already satisfied: rfc3986-validator>=0.1.1 in /opt/anaconda3/envs/py312/lib/python3.12/site-packages (from jupyter-events>=0.9.0->jupyter-server->jupyter-nbextensions-configurator>=0.4.0->jupyter-contrib-nbextensions) (0.1.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/anaconda3/envs/py312/lib/python3.12/site-packages (from requests>=2.31->jupyterlab-server<3,>=2.27.1->notebook>=6.0->jupyter-contrib-nbextensions) (2.0.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/anaconda3/envs/py312/lib/python3.12/site-packages (from requests>=2.31->jupyterlab-server<3,>=2.27.1->notebook>=6.0->jupyter-contrib-nbextensions) (2.1.0)
# Requirement already satisfied: ptyprocess in /opt/anaconda3/envs/py312/lib/python3.12/site-packages (from terminado>=0.8.3->jupyter-server->jupyter-nbextensions-configurator>=0.4.0->jupyter-contrib-nbextensions) (0.7.0)
# Requirement already satisfied: decorator in /opt/anaconda3/envs/py312/lib/python3.12/site-packages (from ipython>=7.23.1->ipykernel>=6.5.0->jupyterlab<4.3,>=4.2.0->notebook>=6.0->jupyter-contrib-nbextensions) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in /opt/anaconda3/envs/py312/lib/python3.12/site-packages (from ipython>=7.23.1->ipykernel>=6.5.0->jupyterlab<4.3,>=4.2.0->notebook>=6.0->jupyter-contrib-nbextensions) (0.19.1)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.41 in /opt/anaconda3/envs/py312/lib/python3.12/site-packages (from ipython>=7.23.1->ipykernel>=6.5.0->jupyterlab<4.3,>=4.2.0->notebook>=6.0->jupyter-contrib-nbextensions) (3.0.42)
# Requirement already satisfied: stack-data in /opt/anaconda3/envs/py312/lib/python3.12/site-packages (from ipython>=7.23.1->ipykernel>=6.5.0->jupyterlab<4.3,>=4.2.0->notebook>=6.0->jupyter-contrib-nbextensions) (0.6.2)
# Requirement already satisfied: pexpect>4.3 in /opt/anaconda3/envs/py312/lib/python3.12/site-packages (from ipython>=7.23.1->ipykernel>=6.5.0->jupyterlab<4.3,>=4.2.0->notebook>=6.0->jupyter-contrib-nbextensions) (4.9.0)
# Requirement already satisfied: fqdn in /opt/anaconda3/envs/py312/lib/python3.12/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server->jupyter-nbextensions-configurator>=0.4.0->jupyter-contrib-nbextensions) (1.5.1)
# Requirement already satisfied: isoduration in /opt/anaconda3/envs/py312/lib/python3.12/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server->jupyter-nbextensions-configurator>=0.4.0->jupyter-contrib-nbextensions) (20.11.0)
# Requirement already satisfied: jsonpointer>1.13 in /opt/anaconda3/envs/py312/lib/python3.12/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server->jupyter-nbextensions-configurator>=0.4.0->jupyter-contrib-nbextensions) (3.0.0)
# Requirement already satisfied: uri-template in /opt/anaconda3/envs/py312/lib/python3.12/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server->jupyter-nbextensions-configurator>=0.4.0->jupyter-contrib-nbextensions) (1.3.0)
# Requirement already satisfied: webcolors>=24.6.0 in /opt/anaconda3/envs/py312/lib/python3.12/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server->jupyter-nbextensions-configurator>=0.4.0->jupyter-contrib-nbextensions) (24.8.0)
# Requirement already satisfied: cffi>=1.0.1 in /opt/anaconda3/envs/py312/lib/python3.12/site-packages (from argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server->jupyter-nbextensions-configurator>=0.4.0->jupyter-contrib-nbextensions) (1.17.1)
# Requirement already satisfied: pycparser in /opt/anaconda3/envs/py312/lib/python3.12/site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server->jupyter-nbextensions-configurator>=0.4.0->jupyter-contrib-nbextensions) (2.22)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in /opt/anaconda3/envs/py312/lib/python3.12/site-packages (from jedi>=0.16->ipython>=7.23.1->ipykernel>=6.5.0->jupyterlab<4.3,>=4.2.0->notebook>=6.0->jupyter-contrib-nbextensions) (0.8.3)
# Requirement already satisfied: wcwidth in /opt/anaconda3/envs/py312/lib/python3.12/site-packages (from prompt-toolkit<3.1.0,>=3.0.41->ipython>=7.23.1->ipykernel>=6.5.0->jupyterlab<4.3,>=4.2.0->notebook>=6.0->jupyter-contrib-nbextensions) (0.2.13)
# Requirement already satisfied: arrow>=0.15.0 in /opt/anaconda3/envs/py312/lib/python3.12/site-packages (from isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server->jupyter-nbextensions-configurator>=0.4.0->jupyter-contrib-nbextensions) (1.3.0)
# Requirement already satisfied: executing>=1.2.0 in /opt/anaconda3/envs/py312/lib/python3.12/site-packages (from stack-data->ipython>=7.23.1->ipykernel>=6.5.0->jupyterlab<4.3,>=4.2.0->notebook>=6.0->jupyter-contrib-nbextensions) (2.0.1)
# Requirement already satisfied: asttokens>=2.1.0 in /opt/anaconda3/envs/py312/lib/python3.12/site-packages (from stack-data->ipython>=7.23.1->ipykernel>=6.5.0->jupyterlab<4.3,>=4.2.0->notebook>=6.0->jupyter-contrib-nbextensions) (2.4.1)
# Requirement already satisfied: pure-eval in /opt/anaconda3/envs/py312/lib/python3.12/site-packages (from stack-data->ipython>=7.23.1->ipykernel>=6.5.0->jupyterlab<4.3,>=4.2.0->notebook>=6.0->jupyter-contrib-nbextensions) (0.2.2)
# Requirement already satisfied: types-python-dateutil>=2.8.10 in /opt/anaconda3/envs/py312/lib/python3.12/site-packages (from arrow>=0.15.0->isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server->jupyter-nbextensions-configurator>=0.4.0->jupyter-contrib-nbextensions) (2.9.0.20240906)
# Installing collected packages: jupyter-contrib-nbextensions
# Successfully installed jupyter-contrib-nbextensions-0.7.0

# %%
! jupyter contrib nbextension install --user
# Out:
# Traceback (most recent call last):
#   File "/opt/anaconda3/envs/py312/lib/python3.12/site-packages/jupyter_contrib_core/notebook_compat/nbextensions.py", line 6, in <module>
#     from notebook.extensions import BaseExtensionApp
# ModuleNotFoundError: No module named 'notebook.extensions'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/opt/anaconda3/envs/py312/lib/python3.12/site-packages/jupyter_contrib_core/notebook_compat/nbextensions.py", line 10, in <module>
#     from notebook.nbextensions import BaseNBExtensionApp
# ModuleNotFoundError: No module named 'notebook.nbextensions'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/opt/anaconda3/envs/py312/bin/jupyter-contrib", line 8, in <module>
#     sys.exit(main())
#              ^^^^^^
#   File "/opt/anaconda3/envs/py312/lib/python3.12/site-packages/jupyter_core/application.py", line 280, in launch_instance
#     super().launch_instance(argv=argv, **kwargs)
#   File "/opt/anaconda3/envs/py312/lib/python3.12/site-packages/traitlets/config/application.py", line 1073, in launch_instance
#     app = cls.instance(**kwargs)
#           ^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/envs/py312/lib/python3.12/site-packages/traitlets/config/configurable.py", line 583, in instance
#     inst = cls(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/envs/py312/lib/python3.12/site-packages/jupyter_contrib_core/application.py", line 27, in __init__
#     self._refresh_subcommands()
#   File "/opt/anaconda3/envs/py312/lib/python3.12/site-packages/jupyter_contrib_core/application.py", line 43, in _refresh_subcommands
#     get_subcommands_dict = entrypoint.load()
#                            ^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/envs/py312/lib/python3.12/site-packages/pkg_resources/__init__.py", line 2518, in load
#     return self.resolve()
#            ^^^^^^^^^^^^^^
#   File "/opt/anaconda3/envs/py312/lib/python3.12/site-packages/pkg_resources/__init__.py", line 2524, in resolve
#     module = __import__(self.module_name, fromlist=['__name__'], level=0)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/envs/py312/lib/python3.12/site-packages/jupyter_contrib_nbextensions/application.py", line 7, in <module>
#     from jupyter_contrib_core.notebook_compat.nbextensions import ArgumentConflict
#   File "/opt/anaconda3/envs/py312/lib/python3.12/site-packages/jupyter_contrib_core/notebook_compat/nbextensions.py", line 12, in <module>
#     from ._compat.nbextensions import BaseNBExtensionApp
#   File "/opt/anaconda3/envs/py312/lib/python3.12/site-packages/jupyter_contrib_core/notebook_compat/_compat/nbextensions.py", line 35, in <module>
#     from notebook.nbextensions import (
# ModuleNotFoundError: No module named 'notebook.nbextensions'

# %%
! pip install --upgrade notebook
# Out:
# Requirement already satisfied: notebook in /opt/anaconda3/envs/py312/lib/python3.12/site-packages (7.2.2)
# Requirement already satisfied: jupyter-server<3,>=2.4.0 in /opt/anaconda3/envs/py312/lib/python3.12/site-packages (from notebook) (2.14.2)
# Requirement already satisfied: jupyterlab-server<3,>=2.27.1 in /opt/anaconda3/envs/py312/lib/python3.12/site-packages (from notebook) (2.27.3)
# Requirement already satisfied: jupyterlab<4.3,>=4.2.0 in /opt/anaconda3/envs/py312/lib/python3.12/site-packages (from notebook) (4.2.5)
# Requirement already satisfied: notebook-shim<0.3,>=0.2 in /opt/anaconda3/envs/py312/lib/python3.12/site-packages (from notebook) (0.2.4)
# Requirement already satisfied: tornado>=6.2.0 in /opt/anaconda3/envs/py312/lib/python3.12/site-packages (from notebook) (6.3.3)
# Requirement already satisfied: anyio>=3.1.0 in /opt/anaconda3/envs/py312/lib/python3.12/site-packages (from jupyter-server<3,>=2.4.0->notebook) (4.4.0)
# Requirement already satisfied: argon2-cffi>=21.1 in /opt/anaconda3/envs/py312/lib/python3.12/site-packages (from jupyter-server<3,>=2.4.0->notebook) (23.1.0)
# Requirement already satisfied: jinja2>=3.0.3 in /opt/anaconda3/envs/py312/lib/python3.12/site-packages (from jupyter-server<3,>=2.4.0->notebook) (3.1.4)
# Requirement already satisfied: jupyter-client>=7.4.4 in /opt/anaconda3/envs/py312/lib/python3.12/site-packages (from jupyter-server<3,>=2.4.0->notebook) (8.6.1)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in /opt/anaconda3/envs/py312/lib/python3.12/site-packages (from jupyter-server<3,>=2.4.0->notebook) (5.5.0)
# Requirement already satisfied: jupyter-events>=0.9.0 in /opt/anaconda3/envs/py312/lib/python3.12/site-packages (from jupyter-server<3,>=2.4.0->notebook) (0.10.0)
# Requirement already satisfied: jupyter-server-terminals>=0.4.4 in /opt/anaconda3/envs/py312/lib/python3.12/site-packages (from jupyter-server<3,>=2.4.0->notebook) (0.5.3)
# Requirement already satisfied: nbconvert>=6.4.4 in /opt/anaconda3/envs/py312/lib/python3.12/site-packages (from jupyter-server<3,>=2.4.0->notebook) (7.16.4)
# Requirement already satisfied: nbformat>=5.3.0 in /opt/anaconda3/envs/py312/lib/python3.12/site-packages (from jupyter-server<3,>=2.4.0->notebook) (5.10.4)
# Requirement already satisfied: overrides>=5.0 in /opt/anaconda3/envs/py312/lib/python3.12/site-packages (from jupyter-server<3,>=2.4.0->notebook) (7.7.0)
# Requirement already satisfied: packaging>=22.0 in /opt/anaconda3/envs/py312/lib/python3.12/site-packages (from jupyter-server<3,>=2.4.0->notebook) (24.0)
# Requirement already satisfied: prometheus-client>=0.9 in /opt/anaconda3/envs/py312/lib/python3.12/site-packages (from jupyter-server<3,>=2.4.0->notebook) (0.20.0)
# Requirement already satisfied: pyzmq>=24 in /opt/anaconda3/envs/py312/lib/python3.12/site-packages (from jupyter-server<3,>=2.4.0->notebook) (25.1.2)
# Requirement already satisfied: send2trash>=1.8.2 in /opt/anaconda3/envs/py312/lib/python3.12/site-packages (from jupyter-server<3,>=2.4.0->notebook) (1.8.3)
# Requirement already satisfied: terminado>=0.8.3 in /opt/anaconda3/envs/py312/lib/python3.12/site-packages (from jupyter-server<3,>=2.4.0->notebook) (0.18.1)
# Requirement already satisfied: traitlets>=5.6.0 in /opt/anaconda3/envs/py312/lib/python3.12/site-packages (from jupyter-server<3,>=2.4.0->notebook) (5.14.2)
# Requirement already satisfied: websocket-client>=1.7 in /opt/anaconda3/envs/py312/lib/python3.12/site-packages (from jupyter-server<3,>=2.4.0->notebook) (1.8.0)
# Requirement already satisfied: async-lru>=1.0.0 in /opt/anaconda3/envs/py312/lib/python3.12/site-packages (from jupyterlab<4.3,>=4.2.0->notebook) (2.0.4)
# Requirement already satisfied: httpx>=0.25.0 in /opt/anaconda3/envs/py312/lib/python3.12/site-packages (from jupyterlab<4.3,>=4.2.0->notebook) (0.27.2)
# Requirement already satisfied: ipykernel>=6.5.0 in /opt/anaconda3/envs/py312/lib/python3.12/site-packages (from jupyterlab<4.3,>=4.2.0->notebook) (6.29.3)
# Requirement already satisfied: jupyter-lsp>=2.0.0 in /opt/anaconda3/envs/py312/lib/python3.12/site-packages (from jupyterlab<4.3,>=4.2.0->notebook) (2.2.5)
# Requirement already satisfied: setuptools>=40.1.0 in /opt/anaconda3/envs/py312/lib/python3.12/site-packages (from jupyterlab<4.3,>=4.2.0->notebook) (68.2.2)
# Requirement already satisfied: babel>=2.10 in /opt/anaconda3/envs/py312/lib/python3.12/site-packages (from jupyterlab-server<3,>=2.27.1->notebook) (2.16.0)
# Requirement already satisfied: json5>=0.9.0 in /opt/anaconda3/envs/py312/lib/python3.12/site-packages (from jupyterlab-server<3,>=2.27.1->notebook) (0.9.25)
# Requirement already satisfied: jsonschema>=4.18.0 in /opt/anaconda3/envs/py312/lib/python3.12/site-packages (from jupyterlab-server<3,>=2.27.1->notebook) (4.23.0)
# Requirement already satisfied: requests>=2.31 in /opt/anaconda3/envs/py312/lib/python3.12/site-packages (from jupyterlab-server<3,>=2.27.1->notebook) (2.31.0)
# Requirement already satisfied: idna>=2.8 in /opt/anaconda3/envs/py312/lib/python3.12/site-packages (from anyio>=3.1.0->jupyter-server<3,>=2.4.0->notebook) (3.4)
# Requirement already satisfied: sniffio>=1.1 in /opt/anaconda3/envs/py312/lib/python3.12/site-packages (from anyio>=3.1.0->jupyter-server<3,>=2.4.0->notebook) (1.3.1)
# Requirement already satisfied: argon2-cffi-bindings in /opt/anaconda3/envs/py312/lib/python3.12/site-packages (from argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->notebook) (21.2.0)
# Requirement already satisfied: certifi in /opt/anaconda3/envs/py312/lib/python3.12/site-packages (from httpx>=0.25.0->jupyterlab<4.3,>=4.2.0->notebook) (2024.2.2)
# Requirement already satisfied: httpcore==1.* in /opt/anaconda3/envs/py312/lib/python3.12/site-packages (from httpx>=0.25.0->jupyterlab<4.3,>=4.2.0->notebook) (1.0.5)
# Requirement already satisfied: h11<0.15,>=0.13 in /opt/anaconda3/envs/py312/lib/python3.12/site-packages (from httpcore==1.*->httpx>=0.25.0->jupyterlab<4.3,>=4.2.0->notebook) (0.14.0)
# Requirement already satisfied: appnope in /opt/anaconda3/envs/py312/lib/python3.12/site-packages (from ipykernel>=6.5.0->jupyterlab<4.3,>=4.2.0->notebook) (0.1.4)
# Requirement already satisfied: comm>=0.1.1 in /opt/anaconda3/envs/py312/lib/python3.12/site-packages (from ipykernel>=6.5.0->jupyterlab<4.3,>=4.2.0->notebook) (0.2.2)
# Requirement already satisfied: debugpy>=1.6.5 in /opt/anaconda3/envs/py312/lib/python3.12/site-packages (from ipykernel>=6.5.0->jupyterlab<4.3,>=4.2.0->notebook) (1.6.7)
# Requirement already satisfied: ipython>=7.23.1 in /opt/anaconda3/envs/py312/lib/python3.12/site-packages (from ipykernel>=6.5.0->jupyterlab<4.3,>=4.2.0->notebook) (8.22.2)
# Requirement already satisfied: matplotlib-inline>=0.1 in /opt/anaconda3/envs/py312/lib/python3.12/site-packages (from ipykernel>=6.5.0->jupyterlab<4.3,>=4.2.0->notebook) (0.1.6)
# Requirement already satisfied: nest-asyncio in /opt/anaconda3/envs/py312/lib/python3.12/site-packages (from ipykernel>=6.5.0->jupyterlab<4.3,>=4.2.0->notebook) (1.6.0)
# Requirement already satisfied: psutil in /opt/anaconda3/envs/py312/lib/python3.12/site-packages (from ipykernel>=6.5.0->jupyterlab<4.3,>=4.2.0->notebook) (5.9.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/anaconda3/envs/py312/lib/python3.12/site-packages (from jinja2>=3.0.3->jupyter-server<3,>=2.4.0->notebook) (2.1.5)
# Requirement already satisfied: attrs>=22.2.0 in /opt/anaconda3/envs/py312/lib/python3.12/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->notebook) (24.2.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /opt/anaconda3/envs/py312/lib/python3.12/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->notebook) (2023.12.1)
# Requirement already satisfied: referencing>=0.28.4 in /opt/anaconda3/envs/py312/lib/python3.12/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->notebook) (0.35.1)
# Requirement already satisfied: rpds-py>=0.7.1 in /opt/anaconda3/envs/py312/lib/python3.12/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->notebook) (0.20.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/anaconda3/envs/py312/lib/python3.12/site-packages (from jupyter-client>=7.4.4->jupyter-server<3,>=2.4.0->notebook) (2.9.0)
# Requirement already satisfied: platformdirs>=2.5 in /opt/anaconda3/envs/py312/lib/python3.12/site-packages (from jupyter-core!=5.0.*,>=4.12->jupyter-server<3,>=2.4.0->notebook) (4.2.0)
# Requirement already satisfied: python-json-logger>=2.0.4 in /opt/anaconda3/envs/py312/lib/python3.12/site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook) (2.0.7)
# Requirement already satisfied: pyyaml>=5.3 in /opt/anaconda3/envs/py312/lib/python3.12/site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook) (6.0.2)
# Requirement already satisfied: rfc3339-validator in /opt/anaconda3/envs/py312/lib/python3.12/site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook) (0.1.4)
# Requirement already satisfied: rfc3986-validator>=0.1.1 in /opt/anaconda3/envs/py312/lib/python3.12/site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook) (0.1.1)
# Requirement already satisfied: beautifulsoup4 in /opt/anaconda3/envs/py312/lib/python3.12/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook) (4.12.3)
# Requirement already satisfied: bleach!=5.0.0 in /opt/anaconda3/envs/py312/lib/python3.12/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook) (6.1.0)
# Requirement already satisfied: defusedxml in /opt/anaconda3/envs/py312/lib/python3.12/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook) (0.7.1)
# Requirement already satisfied: jupyterlab-pygments in /opt/anaconda3/envs/py312/lib/python3.12/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook) (0.3.0)
# Requirement already satisfied: mistune<4,>=2.0.3 in /opt/anaconda3/envs/py312/lib/python3.12/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook) (3.0.2)
# Requirement already satisfied: nbclient>=0.5.0 in /opt/anaconda3/envs/py312/lib/python3.12/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook) (0.10.0)
# Requirement already satisfied: pandocfilters>=1.4.1 in /opt/anaconda3/envs/py312/lib/python3.12/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook) (1.5.1)
# Requirement already satisfied: pygments>=2.4.1 in /opt/anaconda3/envs/py312/lib/python3.12/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook) (2.17.2)
# Requirement already satisfied: tinycss2 in /opt/anaconda3/envs/py312/lib/python3.12/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook) (1.3.0)
# Requirement already satisfied: fastjsonschema>=2.15 in /opt/anaconda3/envs/py312/lib/python3.12/site-packages (from nbformat>=5.3.0->jupyter-server<3,>=2.4.0->notebook) (2.20.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/anaconda3/envs/py312/lib/python3.12/site-packages (from requests>=2.31->jupyterlab-server<3,>=2.27.1->notebook) (2.0.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/anaconda3/envs/py312/lib/python3.12/site-packages (from requests>=2.31->jupyterlab-server<3,>=2.27.1->notebook) (2.1.0)
# Requirement already satisfied: ptyprocess in /opt/anaconda3/envs/py312/lib/python3.12/site-packages (from terminado>=0.8.3->jupyter-server<3,>=2.4.0->notebook) (0.7.0)
# Requirement already satisfied: six>=1.9.0 in /opt/anaconda3/envs/py312/lib/python3.12/site-packages (from bleach!=5.0.0->nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook) (1.16.0)
# Requirement already satisfied: webencodings in /opt/anaconda3/envs/py312/lib/python3.12/site-packages (from bleach!=5.0.0->nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook) (0.5.1)
# Requirement already satisfied: decorator in /opt/anaconda3/envs/py312/lib/python3.12/site-packages (from ipython>=7.23.1->ipykernel>=6.5.0->jupyterlab<4.3,>=4.2.0->notebook) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in /opt/anaconda3/envs/py312/lib/python3.12/site-packages (from ipython>=7.23.1->ipykernel>=6.5.0->jupyterlab<4.3,>=4.2.0->notebook) (0.19.1)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.41 in /opt/anaconda3/envs/py312/lib/python3.12/site-packages (from ipython>=7.23.1->ipykernel>=6.5.0->jupyterlab<4.3,>=4.2.0->notebook) (3.0.42)
# Requirement already satisfied: stack-data in /opt/anaconda3/envs/py312/lib/python3.12/site-packages (from ipython>=7.23.1->ipykernel>=6.5.0->jupyterlab<4.3,>=4.2.0->notebook) (0.6.2)
# Requirement already satisfied: pexpect>4.3 in /opt/anaconda3/envs/py312/lib/python3.12/site-packages (from ipython>=7.23.1->ipykernel>=6.5.0->jupyterlab<4.3,>=4.2.0->notebook) (4.9.0)
# Requirement already satisfied: fqdn in /opt/anaconda3/envs/py312/lib/python3.12/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook) (1.5.1)
# Requirement already satisfied: isoduration in /opt/anaconda3/envs/py312/lib/python3.12/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook) (20.11.0)
# Requirement already satisfied: jsonpointer>1.13 in /opt/anaconda3/envs/py312/lib/python3.12/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook) (3.0.0)
# Requirement already satisfied: uri-template in /opt/anaconda3/envs/py312/lib/python3.12/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook) (1.3.0)
# Requirement already satisfied: webcolors>=24.6.0 in /opt/anaconda3/envs/py312/lib/python3.12/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook) (24.8.0)
# Requirement already satisfied: cffi>=1.0.1 in /opt/anaconda3/envs/py312/lib/python3.12/site-packages (from argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->notebook) (1.17.1)
# Requirement already satisfied: soupsieve>1.2 in /opt/anaconda3/envs/py312/lib/python3.12/site-packages (from beautifulsoup4->nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook) (2.6)
# Requirement already satisfied: pycparser in /opt/anaconda3/envs/py312/lib/python3.12/site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->notebook) (2.22)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in /opt/anaconda3/envs/py312/lib/python3.12/site-packages (from jedi>=0.16->ipython>=7.23.1->ipykernel>=6.5.0->jupyterlab<4.3,>=4.2.0->notebook) (0.8.3)
# Requirement already satisfied: wcwidth in /opt/anaconda3/envs/py312/lib/python3.12/site-packages (from prompt-toolkit<3.1.0,>=3.0.41->ipython>=7.23.1->ipykernel>=6.5.0->jupyterlab<4.3,>=4.2.0->notebook) (0.2.13)
# Requirement already satisfied: arrow>=0.15.0 in /opt/anaconda3/envs/py312/lib/python3.12/site-packages (from isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook) (1.3.0)
# Requirement already satisfied: executing>=1.2.0 in /opt/anaconda3/envs/py312/lib/python3.12/site-packages (from stack-data->ipython>=7.23.1->ipykernel>=6.5.0->jupyterlab<4.3,>=4.2.0->notebook) (2.0.1)
# Requirement already satisfied: asttokens>=2.1.0 in /opt/anaconda3/envs/py312/lib/python3.12/site-packages (from stack-data->ipython>=7.23.1->ipykernel>=6.5.0->jupyterlab<4.3,>=4.2.0->notebook) (2.4.1)
# Requirement already satisfied: pure-eval in /opt/anaconda3/envs/py312/lib/python3.12/site-packages (from stack-data->ipython>=7.23.1->ipykernel>=6.5.0->jupyterlab<4.3,>=4.2.0->notebook) (0.2.2)
# Requirement already satisfied: types-python-dateutil>=2.8.10 in /opt/anaconda3/envs/py312/lib/python3.12/site-packages (from arrow>=0.15.0->isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook) (2.9.0.20240906)

# %%
! pip install --upgrade jupyter-contrib-nbextensions
# Out:
# Requirement already satisfied: jupyter-contrib-nbextensions in /opt/anaconda3/envs/py312/lib/python3.12/site-packages (0.7.0)
# Requirement already satisfied: ipython-genutils in /opt/anaconda3/envs/py312/lib/python3.12/site-packages (from jupyter-contrib-nbextensions) (0.2.0)
# Requirement already satisfied: jupyter-contrib-core>=0.3.3 in /opt/anaconda3/envs/py312/lib/python3.12/site-packages (from jupyter-contrib-nbextensions) (0.4.2)
# Requirement already satisfied: jupyter-core in /opt/anaconda3/envs/py312/lib/python3.12/site-packages (from jupyter-contrib-nbextensions) (5.5.0)
# Requirement already satisfied: jupyter-highlight-selected-word>=0.1.1 in /opt/anaconda3/envs/py312/lib/python3.12/site-packages (from jupyter-contrib-nbextensions) (0.2.0)
# Requirement already satisfied: jupyter-nbextensions-configurator>=0.4.0 in /opt/anaconda3/envs/py312/lib/python3.12/site-packages (from jupyter-contrib-nbextensions) (0.6.4)
# Requirement already satisfied: nbconvert>=6.0 in /opt/anaconda3/envs/py312/lib/python3.12/site-packages (from jupyter-contrib-nbextensions) (7.16.4)
# Requirement already satisfied: notebook>=6.0 in /opt/anaconda3/envs/py312/lib/python3.12/site-packages (from jupyter-contrib-nbextensions) (7.2.2)
# Requirement already satisfied: tornado in /opt/anaconda3/envs/py312/lib/python3.12/site-packages (from jupyter-contrib-nbextensions) (6.3.3)
# Requirement already satisfied: traitlets>=4.1 in /opt/anaconda3/envs/py312/lib/python3.12/site-packages (from jupyter-contrib-nbextensions) (5.14.2)
# Requirement already satisfied: lxml in /opt/anaconda3/envs/py312/lib/python3.12/site-packages (from jupyter-contrib-nbextensions) (5.3.0)
# Requirement already satisfied: setuptools in /opt/anaconda3/envs/py312/lib/python3.12/site-packages (from jupyter-contrib-core>=0.3.3->jupyter-contrib-nbextensions) (68.2.2)
# Requirement already satisfied: jupyter-server in /opt/anaconda3/envs/py312/lib/python3.12/site-packages (from jupyter-nbextensions-configurator>=0.4.0->jupyter-contrib-nbextensions) (2.14.2)
# Requirement already satisfied: pyyaml in /opt/anaconda3/envs/py312/lib/python3.12/site-packages (from jupyter-nbextensions-configurator>=0.4.0->jupyter-contrib-nbextensions) (6.0.2)
# Requirement already satisfied: beautifulsoup4 in /opt/anaconda3/envs/py312/lib/python3.12/site-packages (from nbconvert>=6.0->jupyter-contrib-nbextensions) (4.12.3)
# Requirement already satisfied: bleach!=5.0.0 in /opt/anaconda3/envs/py312/lib/python3.12/site-packages (from nbconvert>=6.0->jupyter-contrib-nbextensions) (6.1.0)
# Requirement already satisfied: defusedxml in /opt/anaconda3/envs/py312/lib/python3.12/site-packages (from nbconvert>=6.0->jupyter-contrib-nbextensions) (0.7.1)
# Requirement already satisfied: jinja2>=3.0 in /opt/anaconda3/envs/py312/lib/python3.12/site-packages (from nbconvert>=6.0->jupyter-contrib-nbextensions) (3.1.4)
# Requirement already satisfied: jupyterlab-pygments in /opt/anaconda3/envs/py312/lib/python3.12/site-packages (from nbconvert>=6.0->jupyter-contrib-nbextensions) (0.3.0)
# Requirement already satisfied: markupsafe>=2.0 in /opt/anaconda3/envs/py312/lib/python3.12/site-packages (from nbconvert>=6.0->jupyter-contrib-nbextensions) (2.1.5)
# Requirement already satisfied: mistune<4,>=2.0.3 in /opt/anaconda3/envs/py312/lib/python3.12/site-packages (from nbconvert>=6.0->jupyter-contrib-nbextensions) (3.0.2)
# Requirement already satisfied: nbclient>=0.5.0 in /opt/anaconda3/envs/py312/lib/python3.12/site-packages (from nbconvert>=6.0->jupyter-contrib-nbextensions) (0.10.0)
# Requirement already satisfied: nbformat>=5.7 in /opt/anaconda3/envs/py312/lib/python3.12/site-packages (from nbconvert>=6.0->jupyter-contrib-nbextensions) (5.10.4)
# Requirement already satisfied: packaging in /opt/anaconda3/envs/py312/lib/python3.12/site-packages (from nbconvert>=6.0->jupyter-contrib-nbextensions) (24.0)
# Requirement already satisfied: pandocfilters>=1.4.1 in /opt/anaconda3/envs/py312/lib/python3.12/site-packages (from nbconvert>=6.0->jupyter-contrib-nbextensions) (1.5.1)
# Requirement already satisfied: pygments>=2.4.1 in /opt/anaconda3/envs/py312/lib/python3.12/site-packages (from nbconvert>=6.0->jupyter-contrib-nbextensions) (2.17.2)
# Requirement already satisfied: tinycss2 in /opt/anaconda3/envs/py312/lib/python3.12/site-packages (from nbconvert>=6.0->jupyter-contrib-nbextensions) (1.3.0)
# Requirement already satisfied: platformdirs>=2.5 in /opt/anaconda3/envs/py312/lib/python3.12/site-packages (from jupyter-core->jupyter-contrib-nbextensions) (4.2.0)
# Requirement already satisfied: jupyterlab-server<3,>=2.27.1 in /opt/anaconda3/envs/py312/lib/python3.12/site-packages (from notebook>=6.0->jupyter-contrib-nbextensions) (2.27.3)
# Requirement already satisfied: jupyterlab<4.3,>=4.2.0 in /opt/anaconda3/envs/py312/lib/python3.12/site-packages (from notebook>=6.0->jupyter-contrib-nbextensions) (4.2.5)
# Requirement already satisfied: notebook-shim<0.3,>=0.2 in /opt/anaconda3/envs/py312/lib/python3.12/site-packages (from notebook>=6.0->jupyter-contrib-nbextensions) (0.2.4)
# Requirement already satisfied: six>=1.9.0 in /opt/anaconda3/envs/py312/lib/python3.12/site-packages (from bleach!=5.0.0->nbconvert>=6.0->jupyter-contrib-nbextensions) (1.16.0)
# Requirement already satisfied: webencodings in /opt/anaconda3/envs/py312/lib/python3.12/site-packages (from bleach!=5.0.0->nbconvert>=6.0->jupyter-contrib-nbextensions) (0.5.1)
# Requirement already satisfied: anyio>=3.1.0 in /opt/anaconda3/envs/py312/lib/python3.12/site-packages (from jupyter-server->jupyter-nbextensions-configurator>=0.4.0->jupyter-contrib-nbextensions) (4.4.0)
# Requirement already satisfied: argon2-cffi>=21.1 in /opt/anaconda3/envs/py312/lib/python3.12/site-packages (from jupyter-server->jupyter-nbextensions-configurator>=0.4.0->jupyter-contrib-nbextensions) (23.1.0)
# Requirement already satisfied: jupyter-client>=7.4.4 in /opt/anaconda3/envs/py312/lib/python3.12/site-packages (from jupyter-server->jupyter-nbextensions-configurator>=0.4.0->jupyter-contrib-nbextensions) (8.6.1)
# Requirement already satisfied: jupyter-events>=0.9.0 in /opt/anaconda3/envs/py312/lib/python3.12/site-packages (from jupyter-server->jupyter-nbextensions-configurator>=0.4.0->jupyter-contrib-nbextensions) (0.10.0)
# Requirement already satisfied: jupyter-server-terminals>=0.4.4 in /opt/anaconda3/envs/py312/lib/python3.12/site-packages (from jupyter-server->jupyter-nbextensions-configurator>=0.4.0->jupyter-contrib-nbextensions) (0.5.3)
# Requirement already satisfied: overrides>=5.0 in /opt/anaconda3/envs/py312/lib/python3.12/site-packages (from jupyter-server->jupyter-nbextensions-configurator>=0.4.0->jupyter-contrib-nbextensions) (7.7.0)
# Requirement already satisfied: prometheus-client>=0.9 in /opt/anaconda3/envs/py312/lib/python3.12/site-packages (from jupyter-server->jupyter-nbextensions-configurator>=0.4.0->jupyter-contrib-nbextensions) (0.20.0)
# Requirement already satisfied: pyzmq>=24 in /opt/anaconda3/envs/py312/lib/python3.12/site-packages (from jupyter-server->jupyter-nbextensions-configurator>=0.4.0->jupyter-contrib-nbextensions) (25.1.2)
# Requirement already satisfied: send2trash>=1.8.2 in /opt/anaconda3/envs/py312/lib/python3.12/site-packages (from jupyter-server->jupyter-nbextensions-configurator>=0.4.0->jupyter-contrib-nbextensions) (1.8.3)
# Requirement already satisfied: terminado>=0.8.3 in /opt/anaconda3/envs/py312/lib/python3.12/site-packages (from jupyter-server->jupyter-nbextensions-configurator>=0.4.0->jupyter-contrib-nbextensions) (0.18.1)
# Requirement already satisfied: websocket-client>=1.7 in /opt/anaconda3/envs/py312/lib/python3.12/site-packages (from jupyter-server->jupyter-nbextensions-configurator>=0.4.0->jupyter-contrib-nbextensions) (1.8.0)
# Requirement already satisfied: async-lru>=1.0.0 in /opt/anaconda3/envs/py312/lib/python3.12/site-packages (from jupyterlab<4.3,>=4.2.0->notebook>=6.0->jupyter-contrib-nbextensions) (2.0.4)
# Requirement already satisfied: httpx>=0.25.0 in /opt/anaconda3/envs/py312/lib/python3.12/site-packages (from jupyterlab<4.3,>=4.2.0->notebook>=6.0->jupyter-contrib-nbextensions) (0.27.2)
# Requirement already satisfied: ipykernel>=6.5.0 in /opt/anaconda3/envs/py312/lib/python3.12/site-packages (from jupyterlab<4.3,>=4.2.0->notebook>=6.0->jupyter-contrib-nbextensions) (6.29.3)
# Requirement already satisfied: jupyter-lsp>=2.0.0 in /opt/anaconda3/envs/py312/lib/python3.12/site-packages (from jupyterlab<4.3,>=4.2.0->notebook>=6.0->jupyter-contrib-nbextensions) (2.2.5)
# Requirement already satisfied: babel>=2.10 in /opt/anaconda3/envs/py312/lib/python3.12/site-packages (from jupyterlab-server<3,>=2.27.1->notebook>=6.0->jupyter-contrib-nbextensions) (2.16.0)
# Requirement already satisfied: json5>=0.9.0 in /opt/anaconda3/envs/py312/lib/python3.12/site-packages (from jupyterlab-server<3,>=2.27.1->notebook>=6.0->jupyter-contrib-nbextensions) (0.9.25)
# Requirement already satisfied: jsonschema>=4.18.0 in /opt/anaconda3/envs/py312/lib/python3.12/site-packages (from jupyterlab-server<3,>=2.27.1->notebook>=6.0->jupyter-contrib-nbextensions) (4.23.0)
# Requirement already satisfied: requests>=2.31 in /opt/anaconda3/envs/py312/lib/python3.12/site-packages (from jupyterlab-server<3,>=2.27.1->notebook>=6.0->jupyter-contrib-nbextensions) (2.31.0)
# Requirement already satisfied: fastjsonschema>=2.15 in /opt/anaconda3/envs/py312/lib/python3.12/site-packages (from nbformat>=5.7->nbconvert>=6.0->jupyter-contrib-nbextensions) (2.20.0)
# Requirement already satisfied: soupsieve>1.2 in /opt/anaconda3/envs/py312/lib/python3.12/site-packages (from beautifulsoup4->nbconvert>=6.0->jupyter-contrib-nbextensions) (2.6)
# Requirement already satisfied: idna>=2.8 in /opt/anaconda3/envs/py312/lib/python3.12/site-packages (from anyio>=3.1.0->jupyter-server->jupyter-nbextensions-configurator>=0.4.0->jupyter-contrib-nbextensions) (3.4)
# Requirement already satisfied: sniffio>=1.1 in /opt/anaconda3/envs/py312/lib/python3.12/site-packages (from anyio>=3.1.0->jupyter-server->jupyter-nbextensions-configurator>=0.4.0->jupyter-contrib-nbextensions) (1.3.1)
# Requirement already satisfied: argon2-cffi-bindings in /opt/anaconda3/envs/py312/lib/python3.12/site-packages (from argon2-cffi>=21.1->jupyter-server->jupyter-nbextensions-configurator>=0.4.0->jupyter-contrib-nbextensions) (21.2.0)
# Requirement already satisfied: certifi in /opt/anaconda3/envs/py312/lib/python3.12/site-packages (from httpx>=0.25.0->jupyterlab<4.3,>=4.2.0->notebook>=6.0->jupyter-contrib-nbextensions) (2024.2.2)
# Requirement already satisfied: httpcore==1.* in /opt/anaconda3/envs/py312/lib/python3.12/site-packages (from httpx>=0.25.0->jupyterlab<4.3,>=4.2.0->notebook>=6.0->jupyter-contrib-nbextensions) (1.0.5)
# Requirement already satisfied: h11<0.15,>=0.13 in /opt/anaconda3/envs/py312/lib/python3.12/site-packages (from httpcore==1.*->httpx>=0.25.0->jupyterlab<4.3,>=4.2.0->notebook>=6.0->jupyter-contrib-nbextensions) (0.14.0)
# Requirement already satisfied: appnope in /opt/anaconda3/envs/py312/lib/python3.12/site-packages (from ipykernel>=6.5.0->jupyterlab<4.3,>=4.2.0->notebook>=6.0->jupyter-contrib-nbextensions) (0.1.4)
# Requirement already satisfied: comm>=0.1.1 in /opt/anaconda3/envs/py312/lib/python3.12/site-packages (from ipykernel>=6.5.0->jupyterlab<4.3,>=4.2.0->notebook>=6.0->jupyter-contrib-nbextensions) (0.2.2)
# Requirement already satisfied: debugpy>=1.6.5 in /opt/anaconda3/envs/py312/lib/python3.12/site-packages (from ipykernel>=6.5.0->jupyterlab<4.3,>=4.2.0->notebook>=6.0->jupyter-contrib-nbextensions) (1.6.7)
# Requirement already satisfied: ipython>=7.23.1 in /opt/anaconda3/envs/py312/lib/python3.12/site-packages (from ipykernel>=6.5.0->jupyterlab<4.3,>=4.2.0->notebook>=6.0->jupyter-contrib-nbextensions) (8.22.2)
# Requirement already satisfied: matplotlib-inline>=0.1 in /opt/anaconda3/envs/py312/lib/python3.12/site-packages (from ipykernel>=6.5.0->jupyterlab<4.3,>=4.2.0->notebook>=6.0->jupyter-contrib-nbextensions) (0.1.6)
# Requirement already satisfied: nest-asyncio in /opt/anaconda3/envs/py312/lib/python3.12/site-packages (from ipykernel>=6.5.0->jupyterlab<4.3,>=4.2.0->notebook>=6.0->jupyter-contrib-nbextensions) (1.6.0)
# Requirement already satisfied: psutil in /opt/anaconda3/envs/py312/lib/python3.12/site-packages (from ipykernel>=6.5.0->jupyterlab<4.3,>=4.2.0->notebook>=6.0->jupyter-contrib-nbextensions) (5.9.0)
# Requirement already satisfied: attrs>=22.2.0 in /opt/anaconda3/envs/py312/lib/python3.12/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->notebook>=6.0->jupyter-contrib-nbextensions) (24.2.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /opt/anaconda3/envs/py312/lib/python3.12/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->notebook>=6.0->jupyter-contrib-nbextensions) (2023.12.1)
# Requirement already satisfied: referencing>=0.28.4 in /opt/anaconda3/envs/py312/lib/python3.12/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->notebook>=6.0->jupyter-contrib-nbextensions) (0.35.1)
# Requirement already satisfied: rpds-py>=0.7.1 in /opt/anaconda3/envs/py312/lib/python3.12/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->notebook>=6.0->jupyter-contrib-nbextensions) (0.20.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/anaconda3/envs/py312/lib/python3.12/site-packages (from jupyter-client>=7.4.4->jupyter-server->jupyter-nbextensions-configurator>=0.4.0->jupyter-contrib-nbextensions) (2.9.0)
# Requirement already satisfied: python-json-logger>=2.0.4 in /opt/anaconda3/envs/py312/lib/python3.12/site-packages (from jupyter-events>=0.9.0->jupyter-server->jupyter-nbextensions-configurator>=0.4.0->jupyter-contrib-nbextensions) (2.0.7)
# Requirement already satisfied: rfc3339-validator in /opt/anaconda3/envs/py312/lib/python3.12/site-packages (from jupyter-events>=0.9.0->jupyter-server->jupyter-nbextensions-configurator>=0.4.0->jupyter-contrib-nbextensions) (0.1.4)
# Requirement already satisfied: rfc3986-validator>=0.1.1 in /opt/anaconda3/envs/py312/lib/python3.12/site-packages (from jupyter-events>=0.9.0->jupyter-server->jupyter-nbextensions-configurator>=0.4.0->jupyter-contrib-nbextensions) (0.1.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/anaconda3/envs/py312/lib/python3.12/site-packages (from requests>=2.31->jupyterlab-server<3,>=2.27.1->notebook>=6.0->jupyter-contrib-nbextensions) (2.0.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/anaconda3/envs/py312/lib/python3.12/site-packages (from requests>=2.31->jupyterlab-server<3,>=2.27.1->notebook>=6.0->jupyter-contrib-nbextensions) (2.1.0)
# Requirement already satisfied: ptyprocess in /opt/anaconda3/envs/py312/lib/python3.12/site-packages (from terminado>=0.8.3->jupyter-server->jupyter-nbextensions-configurator>=0.4.0->jupyter-contrib-nbextensions) (0.7.0)
# Requirement already satisfied: decorator in /opt/anaconda3/envs/py312/lib/python3.12/site-packages (from ipython>=7.23.1->ipykernel>=6.5.0->jupyterlab<4.3,>=4.2.0->notebook>=6.0->jupyter-contrib-nbextensions) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in /opt/anaconda3/envs/py312/lib/python3.12/site-packages (from ipython>=7.23.1->ipykernel>=6.5.0->jupyterlab<4.3,>=4.2.0->notebook>=6.0->jupyter-contrib-nbextensions) (0.19.1)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.41 in /opt/anaconda3/envs/py312/lib/python3.12/site-packages (from ipython>=7.23.1->ipykernel>=6.5.0->jupyterlab<4.3,>=4.2.0->notebook>=6.0->jupyter-contrib-nbextensions) (3.0.42)
# Requirement already satisfied: stack-data in /opt/anaconda3/envs/py312/lib/python3.12/site-packages (from ipython>=7.23.1->ipykernel>=6.5.0->jupyterlab<4.3,>=4.2.0->notebook>=6.0->jupyter-contrib-nbextensions) (0.6.2)
# Requirement already satisfied: pexpect>4.3 in /opt/anaconda3/envs/py312/lib/python3.12/site-packages (from ipython>=7.23.1->ipykernel>=6.5.0->jupyterlab<4.3,>=4.2.0->notebook>=6.0->jupyter-contrib-nbextensions) (4.9.0)
# Requirement already satisfied: fqdn in /opt/anaconda3/envs/py312/lib/python3.12/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server->jupyter-nbextensions-configurator>=0.4.0->jupyter-contrib-nbextensions) (1.5.1)
# Requirement already satisfied: isoduration in /opt/anaconda3/envs/py312/lib/python3.12/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server->jupyter-nbextensions-configurator>=0.4.0->jupyter-contrib-nbextensions) (20.11.0)
# Requirement already satisfied: jsonpointer>1.13 in /opt/anaconda3/envs/py312/lib/python3.12/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server->jupyter-nbextensions-configurator>=0.4.0->jupyter-contrib-nbextensions) (3.0.0)
# Requirement already satisfied: uri-template in /opt/anaconda3/envs/py312/lib/python3.12/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server->jupyter-nbextensions-configurator>=0.4.0->jupyter-contrib-nbextensions) (1.3.0)
# Requirement already satisfied: webcolors>=24.6.0 in /opt/anaconda3/envs/py312/lib/python3.12/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server->jupyter-nbextensions-configurator>=0.4.0->jupyter-contrib-nbextensions) (24.8.0)
# Requirement already satisfied: cffi>=1.0.1 in /opt/anaconda3/envs/py312/lib/python3.12/site-packages (from argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server->jupyter-nbextensions-configurator>=0.4.0->jupyter-contrib-nbextensions) (1.17.1)
# Requirement already satisfied: pycparser in /opt/anaconda3/envs/py312/lib/python3.12/site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server->jupyter-nbextensions-configurator>=0.4.0->jupyter-contrib-nbextensions) (2.22)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in /opt/anaconda3/envs/py312/lib/python3.12/site-packages (from jedi>=0.16->ipython>=7.23.1->ipykernel>=6.5.0->jupyterlab<4.3,>=4.2.0->notebook>=6.0->jupyter-contrib-nbextensions) (0.8.3)
# Requirement already satisfied: wcwidth in /opt/anaconda3/envs/py312/lib/python3.12/site-packages (from prompt-toolkit<3.1.0,>=3.0.41->ipython>=7.23.1->ipykernel>=6.5.0->jupyterlab<4.3,>=4.2.0->notebook>=6.0->jupyter-contrib-nbextensions) (0.2.13)
# Requirement already satisfied: arrow>=0.15.0 in /opt/anaconda3/envs/py312/lib/python3.12/site-packages (from isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server->jupyter-nbextensions-configurator>=0.4.0->jupyter-contrib-nbextensions) (1.3.0)
# Requirement already satisfied: executing>=1.2.0 in /opt/anaconda3/envs/py312/lib/python3.12/site-packages (from stack-data->ipython>=7.23.1->ipykernel>=6.5.0->jupyterlab<4.3,>=4.2.0->notebook>=6.0->jupyter-contrib-nbextensions) (2.0.1)
# Requirement already satisfied: asttokens>=2.1.0 in /opt/anaconda3/envs/py312/lib/python3.12/site-packages (from stack-data->ipython>=7.23.1->ipykernel>=6.5.0->jupyterlab<4.3,>=4.2.0->notebook>=6.0->jupyter-contrib-nbextensions) (2.4.1)
# Requirement already satisfied: pure-eval in /opt/anaconda3/envs/py312/lib/python3.12/site-packages (from stack-data->ipython>=7.23.1->ipykernel>=6.5.0->jupyterlab<4.3,>=4.2.0->notebook>=6.0->jupyter-contrib-nbextensions) (0.2.2)
# Requirement already satisfied: types-python-dateutil>=2.8.10 in /opt/anaconda3/envs/py312/lib/python3.12/site-packages (from arrow>=0.15.0->isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server->jupyter-nbextensions-configurator>=0.4.0->jupyter-contrib-nbextensions) (2.9.0.20240906)

# %%
! pip install jupyter_nbextensions_configurator
# Out:
# Requirement already satisfied: jupyter_nbextensions_configurator in /opt/anaconda3/envs/py312/lib/python3.12/site-packages (0.6.4)
# Requirement already satisfied: jupyter-contrib-core>=0.3.3 in /opt/anaconda3/envs/py312/lib/python3.12/site-packages (from jupyter_nbextensions_configurator) (0.4.2)
# Requirement already satisfied: jupyter-core in /opt/anaconda3/envs/py312/lib/python3.12/site-packages (from jupyter_nbextensions_configurator) (5.5.0)
# Requirement already satisfied: jupyter-server in /opt/anaconda3/envs/py312/lib/python3.12/site-packages (from jupyter_nbextensions_configurator) (2.14.2)
# Requirement already satisfied: notebook>=6.0 in /opt/anaconda3/envs/py312/lib/python3.12/site-packages (from jupyter_nbextensions_configurator) (7.2.2)
# Requirement already satisfied: pyyaml in /opt/anaconda3/envs/py312/lib/python3.12/site-packages (from jupyter_nbextensions_configurator) (6.0.2)
# Requirement already satisfied: tornado in /opt/anaconda3/envs/py312/lib/python3.12/site-packages (from jupyter_nbextensions_configurator) (6.3.3)
# Requirement already satisfied: traitlets in /opt/anaconda3/envs/py312/lib/python3.12/site-packages (from jupyter_nbextensions_configurator) (5.14.2)
# Requirement already satisfied: setuptools in /opt/anaconda3/envs/py312/lib/python3.12/site-packages (from jupyter-contrib-core>=0.3.3->jupyter_nbextensions_configurator) (68.2.2)
# Requirement already satisfied: jupyterlab-server<3,>=2.27.1 in /opt/anaconda3/envs/py312/lib/python3.12/site-packages (from notebook>=6.0->jupyter_nbextensions_configurator) (2.27.3)
# Requirement already satisfied: jupyterlab<4.3,>=4.2.0 in /opt/anaconda3/envs/py312/lib/python3.12/site-packages (from notebook>=6.0->jupyter_nbextensions_configurator) (4.2.5)
# Requirement already satisfied: notebook-shim<0.3,>=0.2 in /opt/anaconda3/envs/py312/lib/python3.12/site-packages (from notebook>=6.0->jupyter_nbextensions_configurator) (0.2.4)
# Requirement already satisfied: anyio>=3.1.0 in /opt/anaconda3/envs/py312/lib/python3.12/site-packages (from jupyter-server->jupyter_nbextensions_configurator) (4.4.0)
# Requirement already satisfied: argon2-cffi>=21.1 in /opt/anaconda3/envs/py312/lib/python3.12/site-packages (from jupyter-server->jupyter_nbextensions_configurator) (23.1.0)
# Requirement already satisfied: jinja2>=3.0.3 in /opt/anaconda3/envs/py312/lib/python3.12/site-packages (from jupyter-server->jupyter_nbextensions_configurator) (3.1.4)
# Requirement already satisfied: jupyter-client>=7.4.4 in /opt/anaconda3/envs/py312/lib/python3.12/site-packages (from jupyter-server->jupyter_nbextensions_configurator) (8.6.1)
# Requirement already satisfied: jupyter-events>=0.9.0 in /opt/anaconda3/envs/py312/lib/python3.12/site-packages (from jupyter-server->jupyter_nbextensions_configurator) (0.10.0)
# Requirement already satisfied: jupyter-server-terminals>=0.4.4 in /opt/anaconda3/envs/py312/lib/python3.12/site-packages (from jupyter-server->jupyter_nbextensions_configurator) (0.5.3)
# Requirement already satisfied: nbconvert>=6.4.4 in /opt/anaconda3/envs/py312/lib/python3.12/site-packages (from jupyter-server->jupyter_nbextensions_configurator) (7.16.4)
# Requirement already satisfied: nbformat>=5.3.0 in /opt/anaconda3/envs/py312/lib/python3.12/site-packages (from jupyter-server->jupyter_nbextensions_configurator) (5.10.4)
# Requirement already satisfied: overrides>=5.0 in /opt/anaconda3/envs/py312/lib/python3.12/site-packages (from jupyter-server->jupyter_nbextensions_configurator) (7.7.0)
# Requirement already satisfied: packaging>=22.0 in /opt/anaconda3/envs/py312/lib/python3.12/site-packages (from jupyter-server->jupyter_nbextensions_configurator) (24.0)
# Requirement already satisfied: prometheus-client>=0.9 in /opt/anaconda3/envs/py312/lib/python3.12/site-packages (from jupyter-server->jupyter_nbextensions_configurator) (0.20.0)
# Requirement already satisfied: pyzmq>=24 in /opt/anaconda3/envs/py312/lib/python3.12/site-packages (from jupyter-server->jupyter_nbextensions_configurator) (25.1.2)
# Requirement already satisfied: send2trash>=1.8.2 in /opt/anaconda3/envs/py312/lib/python3.12/site-packages (from jupyter-server->jupyter_nbextensions_configurator) (1.8.3)
# Requirement already satisfied: terminado>=0.8.3 in /opt/anaconda3/envs/py312/lib/python3.12/site-packages (from jupyter-server->jupyter_nbextensions_configurator) (0.18.1)
# Requirement already satisfied: websocket-client>=1.7 in /opt/anaconda3/envs/py312/lib/python3.12/site-packages (from jupyter-server->jupyter_nbextensions_configurator) (1.8.0)
# Requirement already satisfied: platformdirs>=2.5 in /opt/anaconda3/envs/py312/lib/python3.12/site-packages (from jupyter-core->jupyter_nbextensions_configurator) (4.2.0)
# Requirement already satisfied: idna>=2.8 in /opt/anaconda3/envs/py312/lib/python3.12/site-packages (from anyio>=3.1.0->jupyter-server->jupyter_nbextensions_configurator) (3.4)
# Requirement already satisfied: sniffio>=1.1 in /opt/anaconda3/envs/py312/lib/python3.12/site-packages (from anyio>=3.1.0->jupyter-server->jupyter_nbextensions_configurator) (1.3.1)
# Requirement already satisfied: argon2-cffi-bindings in /opt/anaconda3/envs/py312/lib/python3.12/site-packages (from argon2-cffi>=21.1->jupyter-server->jupyter_nbextensions_configurator) (21.2.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/anaconda3/envs/py312/lib/python3.12/site-packages (from jinja2>=3.0.3->jupyter-server->jupyter_nbextensions_configurator) (2.1.5)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/anaconda3/envs/py312/lib/python3.12/site-packages (from jupyter-client>=7.4.4->jupyter-server->jupyter_nbextensions_configurator) (2.9.0)
# Requirement already satisfied: jsonschema>=4.18.0 in /opt/anaconda3/envs/py312/lib/python3.12/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server->jupyter_nbextensions_configurator) (4.23.0)
# Requirement already satisfied: python-json-logger>=2.0.4 in /opt/anaconda3/envs/py312/lib/python3.12/site-packages (from jupyter-events>=0.9.0->jupyter-server->jupyter_nbextensions_configurator) (2.0.7)
# Requirement already satisfied: referencing in /opt/anaconda3/envs/py312/lib/python3.12/site-packages (from jupyter-events>=0.9.0->jupyter-server->jupyter_nbextensions_configurator) (0.35.1)
# Requirement already satisfied: rfc3339-validator in /opt/anaconda3/envs/py312/lib/python3.12/site-packages (from jupyter-events>=0.9.0->jupyter-server->jupyter_nbextensions_configurator) (0.1.4)
# Requirement already satisfied: rfc3986-validator>=0.1.1 in /opt/anaconda3/envs/py312/lib/python3.12/site-packages (from jupyter-events>=0.9.0->jupyter-server->jupyter_nbextensions_configurator) (0.1.1)
# Requirement already satisfied: async-lru>=1.0.0 in /opt/anaconda3/envs/py312/lib/python3.12/site-packages (from jupyterlab<4.3,>=4.2.0->notebook>=6.0->jupyter_nbextensions_configurator) (2.0.4)
# Requirement already satisfied: httpx>=0.25.0 in /opt/anaconda3/envs/py312/lib/python3.12/site-packages (from jupyterlab<4.3,>=4.2.0->notebook>=6.0->jupyter_nbextensions_configurator) (0.27.2)
# Requirement already satisfied: ipykernel>=6.5.0 in /opt/anaconda3/envs/py312/lib/python3.12/site-packages (from jupyterlab<4.3,>=4.2.0->notebook>=6.0->jupyter_nbextensions_configurator) (6.29.3)
# Requirement already satisfied: jupyter-lsp>=2.0.0 in /opt/anaconda3/envs/py312/lib/python3.12/site-packages (from jupyterlab<4.3,>=4.2.0->notebook>=6.0->jupyter_nbextensions_configurator) (2.2.5)
# Requirement already satisfied: babel>=2.10 in /opt/anaconda3/envs/py312/lib/python3.12/site-packages (from jupyterlab-server<3,>=2.27.1->notebook>=6.0->jupyter_nbextensions_configurator) (2.16.0)
# Requirement already satisfied: json5>=0.9.0 in /opt/anaconda3/envs/py312/lib/python3.12/site-packages (from jupyterlab-server<3,>=2.27.1->notebook>=6.0->jupyter_nbextensions_configurator) (0.9.25)
# Requirement already satisfied: requests>=2.31 in /opt/anaconda3/envs/py312/lib/python3.12/site-packages (from jupyterlab-server<3,>=2.27.1->notebook>=6.0->jupyter_nbextensions_configurator) (2.31.0)
# Requirement already satisfied: beautifulsoup4 in /opt/anaconda3/envs/py312/lib/python3.12/site-packages (from nbconvert>=6.4.4->jupyter-server->jupyter_nbextensions_configurator) (4.12.3)
# Requirement already satisfied: bleach!=5.0.0 in /opt/anaconda3/envs/py312/lib/python3.12/site-packages (from nbconvert>=6.4.4->jupyter-server->jupyter_nbextensions_configurator) (6.1.0)
# Requirement already satisfied: defusedxml in /opt/anaconda3/envs/py312/lib/python3.12/site-packages (from nbconvert>=6.4.4->jupyter-server->jupyter_nbextensions_configurator) (0.7.1)
# Requirement already satisfied: jupyterlab-pygments in /opt/anaconda3/envs/py312/lib/python3.12/site-packages (from nbconvert>=6.4.4->jupyter-server->jupyter_nbextensions_configurator) (0.3.0)
# Requirement already satisfied: mistune<4,>=2.0.3 in /opt/anaconda3/envs/py312/lib/python3.12/site-packages (from nbconvert>=6.4.4->jupyter-server->jupyter_nbextensions_configurator) (3.0.2)
# Requirement already satisfied: nbclient>=0.5.0 in /opt/anaconda3/envs/py312/lib/python3.12/site-packages (from nbconvert>=6.4.4->jupyter-server->jupyter_nbextensions_configurator) (0.10.0)
# Requirement already satisfied: pandocfilters>=1.4.1 in /opt/anaconda3/envs/py312/lib/python3.12/site-packages (from nbconvert>=6.4.4->jupyter-server->jupyter_nbextensions_configurator) (1.5.1)
# Requirement already satisfied: pygments>=2.4.1 in /opt/anaconda3/envs/py312/lib/python3.12/site-packages (from nbconvert>=6.4.4->jupyter-server->jupyter_nbextensions_configurator) (2.17.2)
# Requirement already satisfied: tinycss2 in /opt/anaconda3/envs/py312/lib/python3.12/site-packages (from nbconvert>=6.4.4->jupyter-server->jupyter_nbextensions_configurator) (1.3.0)
# Requirement already satisfied: fastjsonschema>=2.15 in /opt/anaconda3/envs/py312/lib/python3.12/site-packages (from nbformat>=5.3.0->jupyter-server->jupyter_nbextensions_configurator) (2.20.0)
# Requirement already satisfied: ptyprocess in /opt/anaconda3/envs/py312/lib/python3.12/site-packages (from terminado>=0.8.3->jupyter-server->jupyter_nbextensions_configurator) (0.7.0)
# Requirement already satisfied: six>=1.9.0 in /opt/anaconda3/envs/py312/lib/python3.12/site-packages (from bleach!=5.0.0->nbconvert>=6.4.4->jupyter-server->jupyter_nbextensions_configurator) (1.16.0)
# Requirement already satisfied: webencodings in /opt/anaconda3/envs/py312/lib/python3.12/site-packages (from bleach!=5.0.0->nbconvert>=6.4.4->jupyter-server->jupyter_nbextensions_configurator) (0.5.1)
# Requirement already satisfied: certifi in /opt/anaconda3/envs/py312/lib/python3.12/site-packages (from httpx>=0.25.0->jupyterlab<4.3,>=4.2.0->notebook>=6.0->jupyter_nbextensions_configurator) (2024.2.2)
# Requirement already satisfied: httpcore==1.* in /opt/anaconda3/envs/py312/lib/python3.12/site-packages (from httpx>=0.25.0->jupyterlab<4.3,>=4.2.0->notebook>=6.0->jupyter_nbextensions_configurator) (1.0.5)
# Requirement already satisfied: h11<0.15,>=0.13 in /opt/anaconda3/envs/py312/lib/python3.12/site-packages (from httpcore==1.*->httpx>=0.25.0->jupyterlab<4.3,>=4.2.0->notebook>=6.0->jupyter_nbextensions_configurator) (0.14.0)
# Requirement already satisfied: appnope in /opt/anaconda3/envs/py312/lib/python3.12/site-packages (from ipykernel>=6.5.0->jupyterlab<4.3,>=4.2.0->notebook>=6.0->jupyter_nbextensions_configurator) (0.1.4)
# Requirement already satisfied: comm>=0.1.1 in /opt/anaconda3/envs/py312/lib/python3.12/site-packages (from ipykernel>=6.5.0->jupyterlab<4.3,>=4.2.0->notebook>=6.0->jupyter_nbextensions_configurator) (0.2.2)
# Requirement already satisfied: debugpy>=1.6.5 in /opt/anaconda3/envs/py312/lib/python3.12/site-packages (from ipykernel>=6.5.0->jupyterlab<4.3,>=4.2.0->notebook>=6.0->jupyter_nbextensions_configurator) (1.6.7)
# Requirement already satisfied: ipython>=7.23.1 in /opt/anaconda3/envs/py312/lib/python3.12/site-packages (from ipykernel>=6.5.0->jupyterlab<4.3,>=4.2.0->notebook>=6.0->jupyter_nbextensions_configurator) (8.22.2)
# Requirement already satisfied: matplotlib-inline>=0.1 in /opt/anaconda3/envs/py312/lib/python3.12/site-packages (from ipykernel>=6.5.0->jupyterlab<4.3,>=4.2.0->notebook>=6.0->jupyter_nbextensions_configurator) (0.1.6)
# Requirement already satisfied: nest-asyncio in /opt/anaconda3/envs/py312/lib/python3.12/site-packages (from ipykernel>=6.5.0->jupyterlab<4.3,>=4.2.0->notebook>=6.0->jupyter_nbextensions_configurator) (1.6.0)
# Requirement already satisfied: psutil in /opt/anaconda3/envs/py312/lib/python3.12/site-packages (from ipykernel>=6.5.0->jupyterlab<4.3,>=4.2.0->notebook>=6.0->jupyter_nbextensions_configurator) (5.9.0)
# Requirement already satisfied: attrs>=22.2.0 in /opt/anaconda3/envs/py312/lib/python3.12/site-packages (from jsonschema>=4.18.0->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server->jupyter_nbextensions_configurator) (24.2.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /opt/anaconda3/envs/py312/lib/python3.12/site-packages (from jsonschema>=4.18.0->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server->jupyter_nbextensions_configurator) (2023.12.1)
# Requirement already satisfied: rpds-py>=0.7.1 in /opt/anaconda3/envs/py312/lib/python3.12/site-packages (from jsonschema>=4.18.0->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server->jupyter_nbextensions_configurator) (0.20.0)
# Requirement already satisfied: fqdn in /opt/anaconda3/envs/py312/lib/python3.12/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server->jupyter_nbextensions_configurator) (1.5.1)
# Requirement already satisfied: isoduration in /opt/anaconda3/envs/py312/lib/python3.12/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server->jupyter_nbextensions_configurator) (20.11.0)
# Requirement already satisfied: jsonpointer>1.13 in /opt/anaconda3/envs/py312/lib/python3.12/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server->jupyter_nbextensions_configurator) (3.0.0)
# Requirement already satisfied: uri-template in /opt/anaconda3/envs/py312/lib/python3.12/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server->jupyter_nbextensions_configurator) (1.3.0)
# Requirement already satisfied: webcolors>=24.6.0 in /opt/anaconda3/envs/py312/lib/python3.12/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server->jupyter_nbextensions_configurator) (24.8.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/anaconda3/envs/py312/lib/python3.12/site-packages (from requests>=2.31->jupyterlab-server<3,>=2.27.1->notebook>=6.0->jupyter_nbextensions_configurator) (2.0.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/anaconda3/envs/py312/lib/python3.12/site-packages (from requests>=2.31->jupyterlab-server<3,>=2.27.1->notebook>=6.0->jupyter_nbextensions_configurator) (2.1.0)
# Requirement already satisfied: cffi>=1.0.1 in /opt/anaconda3/envs/py312/lib/python3.12/site-packages (from argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server->jupyter_nbextensions_configurator) (1.17.1)
# Requirement already satisfied: soupsieve>1.2 in /opt/anaconda3/envs/py312/lib/python3.12/site-packages (from beautifulsoup4->nbconvert>=6.4.4->jupyter-server->jupyter_nbextensions_configurator) (2.6)
# Requirement already satisfied: pycparser in /opt/anaconda3/envs/py312/lib/python3.12/site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server->jupyter_nbextensions_configurator) (2.22)
# Requirement already satisfied: decorator in /opt/anaconda3/envs/py312/lib/python3.12/site-packages (from ipython>=7.23.1->ipykernel>=6.5.0->jupyterlab<4.3,>=4.2.0->notebook>=6.0->jupyter_nbextensions_configurator) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in /opt/anaconda3/envs/py312/lib/python3.12/site-packages (from ipython>=7.23.1->ipykernel>=6.5.0->jupyterlab<4.3,>=4.2.0->notebook>=6.0->jupyter_nbextensions_configurator) (0.19.1)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.41 in /opt/anaconda3/envs/py312/lib/python3.12/site-packages (from ipython>=7.23.1->ipykernel>=6.5.0->jupyterlab<4.3,>=4.2.0->notebook>=6.0->jupyter_nbextensions_configurator) (3.0.42)
# Requirement already satisfied: stack-data in /opt/anaconda3/envs/py312/lib/python3.12/site-packages (from ipython>=7.23.1->ipykernel>=6.5.0->jupyterlab<4.3,>=4.2.0->notebook>=6.0->jupyter_nbextensions_configurator) (0.6.2)
# Requirement already satisfied: pexpect>4.3 in /opt/anaconda3/envs/py312/lib/python3.12/site-packages (from ipython>=7.23.1->ipykernel>=6.5.0->jupyterlab<4.3,>=4.2.0->notebook>=6.0->jupyter_nbextensions_configurator) (4.9.0)
# Requirement already satisfied: arrow>=0.15.0 in /opt/anaconda3/envs/py312/lib/python3.12/site-packages (from isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server->jupyter_nbextensions_configurator) (1.3.0)
# Requirement already satisfied: types-python-dateutil>=2.8.10 in /opt/anaconda3/envs/py312/lib/python3.12/site-packages (from arrow>=0.15.0->isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server->jupyter_nbextensions_configurator) (2.9.0.20240906)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in /opt/anaconda3/envs/py312/lib/python3.12/site-packages (from jedi>=0.16->ipython>=7.23.1->ipykernel>=6.5.0->jupyterlab<4.3,>=4.2.0->notebook>=6.0->jupyter_nbextensions_configurator) (0.8.3)
# Requirement already satisfied: wcwidth in /opt/anaconda3/envs/py312/lib/python3.12/site-packages (from prompt-toolkit<3.1.0,>=3.0.41->ipython>=7.23.1->ipykernel>=6.5.0->jupyterlab<4.3,>=4.2.0->notebook>=6.0->jupyter_nbextensions_configurator) (0.2.13)
# Requirement already satisfied: executing>=1.2.0 in /opt/anaconda3/envs/py312/lib/python3.12/site-packages (from stack-data->ipython>=7.23.1->ipykernel>=6.5.0->jupyterlab<4.3,>=4.2.0->notebook>=6.0->jupyter_nbextensions_configurator) (2.0.1)
# Requirement already satisfied: asttokens>=2.1.0 in /opt/anaconda3/envs/py312/lib/python3.12/site-packages (from stack-data->ipython>=7.23.1->ipykernel>=6.5.0->jupyterlab<4.3,>=4.2.0->notebook>=6.0->jupyter_nbextensions_configurator) (2.4.1)
# Requirement already satisfied: pure-eval in /opt/anaconda3/envs/py312/lib/python3.12/site-packages (from stack-data->ipython>=7.23.1->ipykernel>=6.5.0->jupyterlab<4.3,>=4.2.0->notebook>=6.0->jupyter_nbextensions_configurator) (0.2.2)

# %%
! pip install jupyterlab
# Out:
# Requirement already satisfied: jupyterlab in /opt/anaconda3/envs/py312/lib/python3.12/site-packages (4.2.5)
# Requirement already satisfied: async-lru>=1.0.0 in /opt/anaconda3/envs/py312/lib/python3.12/site-packages (from jupyterlab) (2.0.4)
# Requirement already satisfied: httpx>=0.25.0 in /opt/anaconda3/envs/py312/lib/python3.12/site-packages (from jupyterlab) (0.27.2)
# Requirement already satisfied: ipykernel>=6.5.0 in /opt/anaconda3/envs/py312/lib/python3.12/site-packages (from jupyterlab) (6.29.3)
# Requirement already satisfied: jinja2>=3.0.3 in /opt/anaconda3/envs/py312/lib/python3.12/site-packages (from jupyterlab) (3.1.4)
# Requirement already satisfied: jupyter-core in /opt/anaconda3/envs/py312/lib/python3.12/site-packages (from jupyterlab) (5.5.0)
# Requirement already satisfied: jupyter-lsp>=2.0.0 in /opt/anaconda3/envs/py312/lib/python3.12/site-packages (from jupyterlab) (2.2.5)
# Requirement already satisfied: jupyter-server<3,>=2.4.0 in /opt/anaconda3/envs/py312/lib/python3.12/site-packages (from jupyterlab) (2.14.2)
# Requirement already satisfied: jupyterlab-server<3,>=2.27.1 in /opt/anaconda3/envs/py312/lib/python3.12/site-packages (from jupyterlab) (2.27.3)
# Requirement already satisfied: notebook-shim>=0.2 in /opt/anaconda3/envs/py312/lib/python3.12/site-packages (from jupyterlab) (0.2.4)
# Requirement already satisfied: packaging in /opt/anaconda3/envs/py312/lib/python3.12/site-packages (from jupyterlab) (24.0)
# Requirement already satisfied: setuptools>=40.1.0 in /opt/anaconda3/envs/py312/lib/python3.12/site-packages (from jupyterlab) (68.2.2)
# Requirement already satisfied: tornado>=6.2.0 in /opt/anaconda3/envs/py312/lib/python3.12/site-packages (from jupyterlab) (6.3.3)
# Requirement already satisfied: traitlets in /opt/anaconda3/envs/py312/lib/python3.12/site-packages (from jupyterlab) (5.14.2)
# Requirement already satisfied: anyio in /opt/anaconda3/envs/py312/lib/python3.12/site-packages (from httpx>=0.25.0->jupyterlab) (4.4.0)
# Requirement already satisfied: certifi in /opt/anaconda3/envs/py312/lib/python3.12/site-packages (from httpx>=0.25.0->jupyterlab) (2024.2.2)
# Requirement already satisfied: httpcore==1.* in /opt/anaconda3/envs/py312/lib/python3.12/site-packages (from httpx>=0.25.0->jupyterlab) (1.0.5)
# Requirement already satisfied: idna in /opt/anaconda3/envs/py312/lib/python3.12/site-packages (from httpx>=0.25.0->jupyterlab) (3.4)
# Requirement already satisfied: sniffio in /opt/anaconda3/envs/py312/lib/python3.12/site-packages (from httpx>=0.25.0->jupyterlab) (1.3.1)
# Requirement already satisfied: h11<0.15,>=0.13 in /opt/anaconda3/envs/py312/lib/python3.12/site-packages (from httpcore==1.*->httpx>=0.25.0->jupyterlab) (0.14.0)
# Requirement already satisfied: appnope in /opt/anaconda3/envs/py312/lib/python3.12/site-packages (from ipykernel>=6.5.0->jupyterlab) (0.1.4)
# Requirement already satisfied: comm>=0.1.1 in /opt/anaconda3/envs/py312/lib/python3.12/site-packages (from ipykernel>=6.5.0->jupyterlab) (0.2.2)
# Requirement already satisfied: debugpy>=1.6.5 in /opt/anaconda3/envs/py312/lib/python3.12/site-packages (from ipykernel>=6.5.0->jupyterlab) (1.6.7)
# Requirement already satisfied: ipython>=7.23.1 in /opt/anaconda3/envs/py312/lib/python3.12/site-packages (from ipykernel>=6.5.0->jupyterlab) (8.22.2)
# Requirement already satisfied: jupyter-client>=6.1.12 in /opt/anaconda3/envs/py312/lib/python3.12/site-packages (from ipykernel>=6.5.0->jupyterlab) (8.6.1)
# Requirement already satisfied: matplotlib-inline>=0.1 in /opt/anaconda3/envs/py312/lib/python3.12/site-packages (from ipykernel>=6.5.0->jupyterlab) (0.1.6)
# Requirement already satisfied: nest-asyncio in /opt/anaconda3/envs/py312/lib/python3.12/site-packages (from ipykernel>=6.5.0->jupyterlab) (1.6.0)
# Requirement already satisfied: psutil in /opt/anaconda3/envs/py312/lib/python3.12/site-packages (from ipykernel>=6.5.0->jupyterlab) (5.9.0)
# Requirement already satisfied: pyzmq>=24 in /opt/anaconda3/envs/py312/lib/python3.12/site-packages (from ipykernel>=6.5.0->jupyterlab) (25.1.2)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/anaconda3/envs/py312/lib/python3.12/site-packages (from jinja2>=3.0.3->jupyterlab) (2.1.5)
# Requirement already satisfied: platformdirs>=2.5 in /opt/anaconda3/envs/py312/lib/python3.12/site-packages (from jupyter-core->jupyterlab) (4.2.0)
# Requirement already satisfied: argon2-cffi>=21.1 in /opt/anaconda3/envs/py312/lib/python3.12/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab) (23.1.0)
# Requirement already satisfied: jupyter-events>=0.9.0 in /opt/anaconda3/envs/py312/lib/python3.12/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab) (0.10.0)
# Requirement already satisfied: jupyter-server-terminals>=0.4.4 in /opt/anaconda3/envs/py312/lib/python3.12/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab) (0.5.3)
# Requirement already satisfied: nbconvert>=6.4.4 in /opt/anaconda3/envs/py312/lib/python3.12/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab) (7.16.4)
# Requirement already satisfied: nbformat>=5.3.0 in /opt/anaconda3/envs/py312/lib/python3.12/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab) (5.10.4)
# Requirement already satisfied: overrides>=5.0 in /opt/anaconda3/envs/py312/lib/python3.12/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab) (7.7.0)
# Requirement already satisfied: prometheus-client>=0.9 in /opt/anaconda3/envs/py312/lib/python3.12/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab) (0.20.0)
# Requirement already satisfied: send2trash>=1.8.2 in /opt/anaconda3/envs/py312/lib/python3.12/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab) (1.8.3)
# Requirement already satisfied: terminado>=0.8.3 in /opt/anaconda3/envs/py312/lib/python3.12/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab) (0.18.1)
# Requirement already satisfied: websocket-client>=1.7 in /opt/anaconda3/envs/py312/lib/python3.12/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab) (1.8.0)
# Requirement already satisfied: babel>=2.10 in /opt/anaconda3/envs/py312/lib/python3.12/site-packages (from jupyterlab-server<3,>=2.27.1->jupyterlab) (2.16.0)
# Requirement already satisfied: json5>=0.9.0 in /opt/anaconda3/envs/py312/lib/python3.12/site-packages (from jupyterlab-server<3,>=2.27.1->jupyterlab) (0.9.25)
# Requirement already satisfied: jsonschema>=4.18.0 in /opt/anaconda3/envs/py312/lib/python3.12/site-packages (from jupyterlab-server<3,>=2.27.1->jupyterlab) (4.23.0)
# Requirement already satisfied: requests>=2.31 in /opt/anaconda3/envs/py312/lib/python3.12/site-packages (from jupyterlab-server<3,>=2.27.1->jupyterlab) (2.31.0)
# Requirement already satisfied: argon2-cffi-bindings in /opt/anaconda3/envs/py312/lib/python3.12/site-packages (from argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->jupyterlab) (21.2.0)
# Requirement already satisfied: decorator in /opt/anaconda3/envs/py312/lib/python3.12/site-packages (from ipython>=7.23.1->ipykernel>=6.5.0->jupyterlab) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in /opt/anaconda3/envs/py312/lib/python3.12/site-packages (from ipython>=7.23.1->ipykernel>=6.5.0->jupyterlab) (0.19.1)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.41 in /opt/anaconda3/envs/py312/lib/python3.12/site-packages (from ipython>=7.23.1->ipykernel>=6.5.0->jupyterlab) (3.0.42)
# Requirement already satisfied: pygments>=2.4.0 in /opt/anaconda3/envs/py312/lib/python3.12/site-packages (from ipython>=7.23.1->ipykernel>=6.5.0->jupyterlab) (2.17.2)
# Requirement already satisfied: stack-data in /opt/anaconda3/envs/py312/lib/python3.12/site-packages (from ipython>=7.23.1->ipykernel>=6.5.0->jupyterlab) (0.6.2)
# Requirement already satisfied: pexpect>4.3 in /opt/anaconda3/envs/py312/lib/python3.12/site-packages (from ipython>=7.23.1->ipykernel>=6.5.0->jupyterlab) (4.9.0)
# Requirement already satisfied: attrs>=22.2.0 in /opt/anaconda3/envs/py312/lib/python3.12/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->jupyterlab) (24.2.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /opt/anaconda3/envs/py312/lib/python3.12/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->jupyterlab) (2023.12.1)
# Requirement already satisfied: referencing>=0.28.4 in /opt/anaconda3/envs/py312/lib/python3.12/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->jupyterlab) (0.35.1)
# Requirement already satisfied: rpds-py>=0.7.1 in /opt/anaconda3/envs/py312/lib/python3.12/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->jupyterlab) (0.20.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/anaconda3/envs/py312/lib/python3.12/site-packages (from jupyter-client>=6.1.12->ipykernel>=6.5.0->jupyterlab) (2.9.0)
# Requirement already satisfied: python-json-logger>=2.0.4 in /opt/anaconda3/envs/py312/lib/python3.12/site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->jupyterlab) (2.0.7)
# Requirement already satisfied: pyyaml>=5.3 in /opt/anaconda3/envs/py312/lib/python3.12/site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->jupyterlab) (6.0.2)
# Requirement already satisfied: rfc3339-validator in /opt/anaconda3/envs/py312/lib/python3.12/site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->jupyterlab) (0.1.4)
# Requirement already satisfied: rfc3986-validator>=0.1.1 in /opt/anaconda3/envs/py312/lib/python3.12/site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->jupyterlab) (0.1.1)
# Requirement already satisfied: beautifulsoup4 in /opt/anaconda3/envs/py312/lib/python3.12/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab) (4.12.3)
# Requirement already satisfied: bleach!=5.0.0 in /opt/anaconda3/envs/py312/lib/python3.12/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab) (6.1.0)
# Requirement already satisfied: defusedxml in /opt/anaconda3/envs/py312/lib/python3.12/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab) (0.7.1)
# Requirement already satisfied: jupyterlab-pygments in /opt/anaconda3/envs/py312/lib/python3.12/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab) (0.3.0)
# Requirement already satisfied: mistune<4,>=2.0.3 in /opt/anaconda3/envs/py312/lib/python3.12/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab) (3.0.2)
# Requirement already satisfied: nbclient>=0.5.0 in /opt/anaconda3/envs/py312/lib/python3.12/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab) (0.10.0)
# Requirement already satisfied: pandocfilters>=1.4.1 in /opt/anaconda3/envs/py312/lib/python3.12/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab) (1.5.1)
# Requirement already satisfied: tinycss2 in /opt/anaconda3/envs/py312/lib/python3.12/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab) (1.3.0)
# Requirement already satisfied: fastjsonschema>=2.15 in /opt/anaconda3/envs/py312/lib/python3.12/site-packages (from nbformat>=5.3.0->jupyter-server<3,>=2.4.0->jupyterlab) (2.20.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/anaconda3/envs/py312/lib/python3.12/site-packages (from requests>=2.31->jupyterlab-server<3,>=2.27.1->jupyterlab) (2.0.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/anaconda3/envs/py312/lib/python3.12/site-packages (from requests>=2.31->jupyterlab-server<3,>=2.27.1->jupyterlab) (2.1.0)
# Requirement already satisfied: ptyprocess in /opt/anaconda3/envs/py312/lib/python3.12/site-packages (from terminado>=0.8.3->jupyter-server<3,>=2.4.0->jupyterlab) (0.7.0)
# Requirement already satisfied: six>=1.9.0 in /opt/anaconda3/envs/py312/lib/python3.12/site-packages (from bleach!=5.0.0->nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab) (1.16.0)
# Requirement already satisfied: webencodings in /opt/anaconda3/envs/py312/lib/python3.12/site-packages (from bleach!=5.0.0->nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab) (0.5.1)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in /opt/anaconda3/envs/py312/lib/python3.12/site-packages (from jedi>=0.16->ipython>=7.23.1->ipykernel>=6.5.0->jupyterlab) (0.8.3)
# Requirement already satisfied: fqdn in /opt/anaconda3/envs/py312/lib/python3.12/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->jupyterlab) (1.5.1)
# Requirement already satisfied: isoduration in /opt/anaconda3/envs/py312/lib/python3.12/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->jupyterlab) (20.11.0)
# Requirement already satisfied: jsonpointer>1.13 in /opt/anaconda3/envs/py312/lib/python3.12/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->jupyterlab) (3.0.0)
# Requirement already satisfied: uri-template in /opt/anaconda3/envs/py312/lib/python3.12/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->jupyterlab) (1.3.0)
# Requirement already satisfied: webcolors>=24.6.0 in /opt/anaconda3/envs/py312/lib/python3.12/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->jupyterlab) (24.8.0)
# Requirement already satisfied: wcwidth in /opt/anaconda3/envs/py312/lib/python3.12/site-packages (from prompt-toolkit<3.1.0,>=3.0.41->ipython>=7.23.1->ipykernel>=6.5.0->jupyterlab) (0.2.13)
# Requirement already satisfied: cffi>=1.0.1 in /opt/anaconda3/envs/py312/lib/python3.12/site-packages (from argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->jupyterlab) (1.17.1)
# Requirement already satisfied: soupsieve>1.2 in /opt/anaconda3/envs/py312/lib/python3.12/site-packages (from beautifulsoup4->nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab) (2.6)
# Requirement already satisfied: executing>=1.2.0 in /opt/anaconda3/envs/py312/lib/python3.12/site-packages (from stack-data->ipython>=7.23.1->ipykernel>=6.5.0->jupyterlab) (2.0.1)
# Requirement already satisfied: asttokens>=2.1.0 in /opt/anaconda3/envs/py312/lib/python3.12/site-packages (from stack-data->ipython>=7.23.1->ipykernel>=6.5.0->jupyterlab) (2.4.1)
# Requirement already satisfied: pure-eval in /opt/anaconda3/envs/py312/lib/python3.12/site-packages (from stack-data->ipython>=7.23.1->ipykernel>=6.5.0->jupyterlab) (0.2.2)
# Requirement already satisfied: pycparser in /opt/anaconda3/envs/py312/lib/python3.12/site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->jupyterlab) (2.22)
# Requirement already satisfied: arrow>=0.15.0 in /opt/anaconda3/envs/py312/lib/python3.12/site-packages (from isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->jupyterlab) (1.3.0)
# Requirement already satisfied: types-python-dateutil>=2.8.10 in /opt/anaconda3/envs/py312/lib/python3.12/site-packages (from arrow>=0.15.0->isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->jupyterlab) (2.9.0.20240906)

# %%
! jupyter contrib nbextension install --user
# Out:
# Traceback (most recent call last):
#   File "/opt/anaconda3/envs/py312/lib/python3.12/site-packages/jupyter_contrib_core/notebook_compat/nbextensions.py", line 6, in <module>
#     from notebook.extensions import BaseExtensionApp
# ModuleNotFoundError: No module named 'notebook.extensions'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/opt/anaconda3/envs/py312/lib/python3.12/site-packages/jupyter_contrib_core/notebook_compat/nbextensions.py", line 10, in <module>
#     from notebook.nbextensions import BaseNBExtensionApp
# ModuleNotFoundError: No module named 'notebook.nbextensions'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/opt/anaconda3/envs/py312/bin/jupyter-contrib", line 8, in <module>
#     sys.exit(main())
#              ^^^^^^
#   File "/opt/anaconda3/envs/py312/lib/python3.12/site-packages/jupyter_core/application.py", line 280, in launch_instance
#     super().launch_instance(argv=argv, **kwargs)
#   File "/opt/anaconda3/envs/py312/lib/python3.12/site-packages/traitlets/config/application.py", line 1073, in launch_instance
#     app = cls.instance(**kwargs)
#           ^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/envs/py312/lib/python3.12/site-packages/traitlets/config/configurable.py", line 583, in instance
#     inst = cls(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/envs/py312/lib/python3.12/site-packages/jupyter_contrib_core/application.py", line 27, in __init__
#     self._refresh_subcommands()
#   File "/opt/anaconda3/envs/py312/lib/python3.12/site-packages/jupyter_contrib_core/application.py", line 43, in _refresh_subcommands
#     get_subcommands_dict = entrypoint.load()
#                            ^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/envs/py312/lib/python3.12/site-packages/pkg_resources/__init__.py", line 2518, in load
#     return self.resolve()
#            ^^^^^^^^^^^^^^
#   File "/opt/anaconda3/envs/py312/lib/python3.12/site-packages/pkg_resources/__init__.py", line 2524, in resolve
#     module = __import__(self.module_name, fromlist=['__name__'], level=0)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/envs/py312/lib/python3.12/site-packages/jupyter_contrib_nbextensions/application.py", line 7, in <module>
#     from jupyter_contrib_core.notebook_compat.nbextensions import ArgumentConflict
#   File "/opt/anaconda3/envs/py312/lib/python3.12/site-packages/jupyter_contrib_core/notebook_compat/nbextensions.py", line 12, in <module>
#     from ._compat.nbextensions import BaseNBExtensionApp
#   File "/opt/anaconda3/envs/py312/lib/python3.12/site-packages/jupyter_contrib_core/notebook_compat/_compat/nbextensions.py", line 35, in <module>
#     from notebook.nbextensions import (
# ModuleNotFoundError: No module named 'notebook.nbextensions'
