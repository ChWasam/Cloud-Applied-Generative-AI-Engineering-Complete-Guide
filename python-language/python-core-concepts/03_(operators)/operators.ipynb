# %% [markdown]
# # Operators

# %% [markdown]
# # 1. Arithmatic Operators
# - + _ * / % // **

# %% [markdown]
# # Importing Table from W3 website containing all arithmatic operators

# %%
! pip install pandas
# Out:
# Collecting pandas
#   Downloading pandas-2.2.1-cp312-cp312-win_amd64.whl.metadata (19 kB)
# Collecting numpy<2,>=1.26.0 (from pandas)
#   Downloading numpy-1.26.4-cp312-cp312-win_amd64.whl.metadata (61 kB)
#      ---------------------------------------- 0.0/61.0 kB ? eta -:--:--
#      ------ --------------------------------- 10.2/61.0 kB ? eta -:--:--
#      ------------------- ------------------ 30.7/61.0 kB 445.2 kB/s eta 0:00:01
#      -------------------------------------- 61.0/61.0 kB 546.2 kB/s eta 0:00:00
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\user\anaconda3\envs\pythonpracticestatic12\lib\site-packages (from pandas) (2.8.2)
# Collecting pytz>=2020.1 (from pandas)
#   Downloading pytz-2024.1-py2.py3-none-any.whl.metadata (22 kB)
# Collecting tzdata>=2022.7 (from pandas)
#   Downloading tzdata-2024.1-py2.py3-none-any.whl.metadata (1.4 kB)
# Requirement already satisfied: six>=1.5 in c:\users\user\anaconda3\envs\pythonpracticestatic12\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Downloading pandas-2.2.1-cp312-cp312-win_amd64.whl (11.5 MB)
#    ---------------------------------------- 0.0/11.5 MB ? eta -:--:--
#    ---------------------------------------- 0.1/11.5 MB 1.7 MB/s eta 0:00:07
#    ---------------------------------------- 0.1/11.5 MB 1.8 MB/s eta 0:00:07
#     --------------------------------------- 0.2/11.5 MB 1.6 MB/s eta 0:00:08
#     --------------------------------------- 0.3/11.5 MB 1.4 MB/s eta 0:00:08
#    - -------------------------------------- 0.3/11.5 MB 1.6 MB/s eta 0:00:07
#    - -------------------------------------- 0.5/11.5 MB 1.7 MB/s eta 0:00:07
#    - -------------------------------------- 0.5/11.5 MB 1.5 MB/s eta 0:00:08
#    - -------------------------------------- 0.6/11.5 MB 1.5 MB/s eta 0:00:08
#    -- ------------------------------------- 0.7/11.5 MB 1.7 MB/s eta 0:00:07
#    -- ------------------------------------- 0.8/11.5 MB 1.7 MB/s eta 0:00:07
#    --- ------------------------------------ 0.9/11.5 MB 1.8 MB/s eta 0:00:07
#    --- ------------------------------------ 0.9/11.5 MB 1.8 MB/s eta 0:00:06
#    --- ------------------------------------ 1.0/11.5 MB 1.7 MB/s eta 0:00:07
#    --- ------------------------------------ 1.1/11.5 MB 1.7 MB/s eta 0:00:07
#    ---- ----------------------------------- 1.2/11.5 MB 1.8 MB/s eta 0:00:06
#    ---- ----------------------------------- 1.3/11.5 MB 1.8 MB/s eta 0:00:06
#    ----- ---------------------------------- 1.5/11.5 MB 1.8 MB/s eta 0:00:06
#    ----- ---------------------------------- 1.6/11.5 MB 1.9 MB/s eta 0:00:06
#    ----- ---------------------------------- 1.6/11.5 MB 1.8 MB/s eta 0:00:06
#    ------ --------------------------------- 1.7/11.5 MB 1.9 MB/s eta 0:00:06
#    ------ --------------------------------- 1.8/11.5 MB 1.9 MB/s eta 0:00:06
#    ------ --------------------------------- 1.9/11.5 MB 1.8 MB/s eta 0:00:06
#    ------ --------------------------------- 2.0/11.5 MB 1.9 MB/s eta 0:00:05
#    ------- -------------------------------- 2.1/11.5 MB 1.9 MB/s eta 0:00:05
#    ------- -------------------------------- 2.3/11.5 MB 1.9 MB/s eta 0:00:05
#    -------- ------------------------------- 2.4/11.5 MB 2.0 MB/s eta 0:00:05
#    -------- ------------------------------- 2.5/11.5 MB 2.0 MB/s eta 0:00:05
#    --------- ------------------------------ 2.6/11.5 MB 2.0 MB/s eta 0:00:05
#    --------- ------------------------------ 2.7/11.5 MB 2.0 MB/s eta 0:00:05
#    --------- ------------------------------ 2.8/11.5 MB 2.0 MB/s eta 0:00:05
#    ---------- ----------------------------- 2.9/11.5 MB 2.0 MB/s eta 0:00:05
#    ---------- ----------------------------- 3.1/11.5 MB 2.0 MB/s eta 0:00:05
#    ----------- ---------------------------- 3.2/11.5 MB 2.1 MB/s eta 0:00:05
#    ----------- ---------------------------- 3.3/11.5 MB 2.1 MB/s eta 0:00:04
#    ----------- ---------------------------- 3.4/11.5 MB 2.1 MB/s eta 0:00:04
#    ------------ --------------------------- 3.5/11.5 MB 2.1 MB/s eta 0:00:04
#    ------------ --------------------------- 3.7/11.5 MB 2.1 MB/s eta 0:00:04
#    ------------- -------------------------- 3.8/11.5 MB 2.1 MB/s eta 0:00:04
#    ------------- -------------------------- 3.9/11.5 MB 2.1 MB/s eta 0:00:04
#    -------------- ------------------------- 4.0/11.5 MB 2.1 MB/s eta 0:00:04
#    -------------- ------------------------- 4.2/11.5 MB 2.1 MB/s eta 0:00:04
#    -------------- ------------------------- 4.3/11.5 MB 2.2 MB/s eta 0:00:04
#    --------------- ------------------------ 4.4/11.5 MB 2.2 MB/s eta 0:00:04
#    --------------- ------------------------ 4.5/11.5 MB 2.2 MB/s eta 0:00:04
#    ---------------- ----------------------- 4.7/11.5 MB 2.2 MB/s eta 0:00:04
#    ---------------- ----------------------- 4.8/11.5 MB 2.2 MB/s eta 0:00:04
#    ----------------- ---------------------- 4.9/11.5 MB 2.2 MB/s eta 0:00:04
#    ----------------- ---------------------- 5.0/11.5 MB 2.2 MB/s eta 0:00:03
#    ------------------ --------------------- 5.2/11.5 MB 2.2 MB/s eta 0:00:03
#    ------------------ --------------------- 5.3/11.5 MB 2.2 MB/s eta 0:00:03
#    ------------------ --------------------- 5.4/11.5 MB 2.2 MB/s eta 0:00:03
#    ------------------- -------------------- 5.6/11.5 MB 2.2 MB/s eta 0:00:03
#    ------------------- -------------------- 5.7/11.5 MB 2.2 MB/s eta 0:00:03
#    -------------------- ------------------- 5.8/11.5 MB 2.2 MB/s eta 0:00:03
#    -------------------- ------------------- 6.0/11.5 MB 2.2 MB/s eta 0:00:03
#    --------------------- ------------------ 6.1/11.5 MB 2.2 MB/s eta 0:00:03
#    --------------------- ------------------ 6.3/11.5 MB 2.2 MB/s eta 0:00:03
#    ---------------------- ----------------- 6.4/11.5 MB 2.2 MB/s eta 0:00:03
#    ---------------------- ----------------- 6.5/11.5 MB 2.2 MB/s eta 0:00:03
#    ----------------------- ---------------- 6.6/11.5 MB 2.2 MB/s eta 0:00:03
#    ----------------------- ---------------- 6.7/11.5 MB 2.2 MB/s eta 0:00:03
#    ----------------------- ---------------- 6.8/11.5 MB 2.3 MB/s eta 0:00:03
#    ------------------------ --------------- 7.0/11.5 MB 2.3 MB/s eta 0:00:03
#    ------------------------ --------------- 7.1/11.5 MB 2.3 MB/s eta 0:00:02
#    ------------------------- -------------- 7.2/11.5 MB 2.3 MB/s eta 0:00:02
#    ------------------------- -------------- 7.3/11.5 MB 2.3 MB/s eta 0:00:02
#    -------------------------- ------------- 7.5/11.5 MB 2.3 MB/s eta 0:00:02
#    -------------------------- ------------- 7.7/11.5 MB 2.3 MB/s eta 0:00:02
#    --------------------------- ------------ 7.8/11.5 MB 2.3 MB/s eta 0:00:02
#    --------------------------- ------------ 7.9/11.5 MB 2.3 MB/s eta 0:00:02
#    ---------------------------- ----------- 8.1/11.5 MB 2.3 MB/s eta 0:00:02
#    ---------------------------- ----------- 8.2/11.5 MB 2.3 MB/s eta 0:00:02
#    ---------------------------- ----------- 8.3/11.5 MB 2.3 MB/s eta 0:00:02
#    ----------------------------- ---------- 8.4/11.5 MB 2.3 MB/s eta 0:00:02
#    ----------------------------- ---------- 8.5/11.5 MB 2.3 MB/s eta 0:00:02
#    ------------------------------ --------- 8.6/11.5 MB 2.3 MB/s eta 0:00:02
#    ------------------------------ --------- 8.7/11.5 MB 2.3 MB/s eta 0:00:02
#    ------------------------------ --------- 8.9/11.5 MB 2.3 MB/s eta 0:00:02
#    ------------------------------- -------- 9.0/11.5 MB 2.3 MB/s eta 0:00:02
#    ------------------------------- -------- 9.1/11.5 MB 2.3 MB/s eta 0:00:02
#    -------------------------------- ------- 9.2/11.5 MB 2.3 MB/s eta 0:00:01
#    -------------------------------- ------- 9.3/11.5 MB 2.3 MB/s eta 0:00:01
#    -------------------------------- ------- 9.5/11.5 MB 2.3 MB/s eta 0:00:01
#    --------------------------------- ------ 9.5/11.5 MB 2.3 MB/s eta 0:00:01
#    --------------------------------- ------ 9.5/11.5 MB 2.3 MB/s eta 0:00:01
#    --------------------------------- ------ 9.5/11.5 MB 2.3 MB/s eta 0:00:01
#    --------------------------------- ------ 9.5/11.5 MB 2.3 MB/s eta 0:00:01
#    --------------------------------- ------ 9.7/11.5 MB 2.2 MB/s eta 0:00:01
#    --------------------------------- ------ 9.7/11.5 MB 2.2 MB/s eta 0:00:01
#    ---------------------------------- ----- 9.9/11.5 MB 2.2 MB/s eta 0:00:01
#    ------------------------------------ --- 10.4/11.5 MB 2.3 MB/s eta 0:00:01
#    ------------------------------------ --- 10.5/11.5 MB 2.3 MB/s eta 0:00:01
#    ------------------------------------ --- 10.6/11.5 MB 2.4 MB/s eta 0:00:01
#    ------------------------------------- -- 10.7/11.5 MB 2.4 MB/s eta 0:00:01
#    ------------------------------------- -- 10.8/11.5 MB 2.4 MB/s eta 0:00:01
#    -------------------------------------- - 10.9/11.5 MB 2.4 MB/s eta 0:00:01
#    -------------------------------------- - 11.1/11.5 MB 2.4 MB/s eta 0:00:01
#    -------------------------------------- - 11.2/11.5 MB 2.4 MB/s eta 0:00:01
#    ---------------------------------------  11.3/11.5 MB 2.4 MB/s eta 0:00:01
#    ---------------------------------------  11.4/11.5 MB 2.4 MB/s eta 0:00:01
#    ---------------------------------------  11.5/11.5 MB 2.4 MB/s eta 0:00:01
#    ---------------------------------------- 11.5/11.5 MB 2.4 MB/s eta 0:00:00
# Downloading numpy-1.26.4-cp312-cp312-win_amd64.whl (15.5 MB)
#    ---------------------------------------- 0.0/15.5 MB ? eta -:--:--
#    ---------------------------------------- 0.2/15.5 MB 3.5 MB/s eta 0:00:05
#     --------------------------------------- 0.4/15.5 MB 3.2 MB/s eta 0:00:05
#    - -------------------------------------- 0.5/15.5 MB 2.8 MB/s eta 0:00:06
#    - -------------------------------------- 0.6/15.5 MB 2.7 MB/s eta 0:00:06
#    -- ------------------------------------- 1.0/15.5 MB 2.6 MB/s eta 0:00:06
#    --- ------------------------------------ 1.2/15.5 MB 2.6 MB/s eta 0:00:06
#    --- ------------------------------------ 1.3/15.5 MB 2.5 MB/s eta 0:00:06
#    --- ------------------------------------ 1.5/15.5 MB 2.5 MB/s eta 0:00:06
#    ---- ----------------------------------- 1.6/15.5 MB 2.6 MB/s eta 0:00:06
#    ---- ----------------------------------- 1.7/15.5 MB 2.5 MB/s eta 0:00:06
#    ---- ----------------------------------- 1.8/15.5 MB 2.5 MB/s eta 0:00:06
#    ---- ----------------------------------- 1.9/15.5 MB 2.5 MB/s eta 0:00:06
#    ----- ---------------------------------- 2.0/15.5 MB 2.5 MB/s eta 0:00:06
#    ----- ---------------------------------- 2.1/15.5 MB 2.5 MB/s eta 0:00:06
#    ----- ---------------------------------- 2.3/15.5 MB 2.5 MB/s eta 0:00:06
#    ----- ---------------------------------- 2.3/15.5 MB 2.5 MB/s eta 0:00:06
#    ------ --------------------------------- 2.5/15.5 MB 2.5 MB/s eta 0:00:06
#    ------ --------------------------------- 2.6/15.5 MB 2.5 MB/s eta 0:00:06
#    ------ --------------------------------- 2.7/15.5 MB 2.5 MB/s eta 0:00:06
#    ------- -------------------------------- 2.8/15.5 MB 2.5 MB/s eta 0:00:06
#    ------- -------------------------------- 2.9/15.5 MB 2.5 MB/s eta 0:00:06
#    ------- -------------------------------- 3.0/15.5 MB 2.5 MB/s eta 0:00:06
#    -------- ------------------------------- 3.1/15.5 MB 2.5 MB/s eta 0:00:05
#    -------- ------------------------------- 3.3/15.5 MB 2.5 MB/s eta 0:00:05
#    -------- ------------------------------- 3.4/15.5 MB 2.5 MB/s eta 0:00:05
#    -------- ------------------------------- 3.5/15.5 MB 2.5 MB/s eta 0:00:05
#    --------- ------------------------------ 3.6/15.5 MB 2.5 MB/s eta 0:00:05
#    --------- ------------------------------ 3.7/15.5 MB 2.5 MB/s eta 0:00:05
#    --------- ------------------------------ 3.8/15.5 MB 2.5 MB/s eta 0:00:05
#    ---------- ----------------------------- 4.0/15.5 MB 2.5 MB/s eta 0:00:05
#    ---------- ----------------------------- 4.1/15.5 MB 2.5 MB/s eta 0:00:05
#    ---------- ----------------------------- 4.2/15.5 MB 2.5 MB/s eta 0:00:05
#    ----------- ---------------------------- 4.3/15.5 MB 2.5 MB/s eta 0:00:05
#    ----------- ---------------------------- 4.5/15.5 MB 2.5 MB/s eta 0:00:05
#    ----------- ---------------------------- 4.6/15.5 MB 2.5 MB/s eta 0:00:05
#    ------------ --------------------------- 4.7/15.5 MB 2.5 MB/s eta 0:00:05
#    ------------ --------------------------- 4.9/15.5 MB 2.5 MB/s eta 0:00:05
#    ------------ --------------------------- 5.0/15.5 MB 2.5 MB/s eta 0:00:05
#    ------------- -------------------------- 5.1/15.5 MB 2.5 MB/s eta 0:00:05
#    ------------- -------------------------- 5.2/15.5 MB 2.5 MB/s eta 0:00:05
#    ------------- -------------------------- 5.3/15.5 MB 2.5 MB/s eta 0:00:05
#    ------------- -------------------------- 5.3/15.5 MB 2.5 MB/s eta 0:00:05
#    ------------- -------------------------- 5.3/15.5 MB 2.5 MB/s eta 0:00:05
#    ------------- -------------------------- 5.3/15.5 MB 2.5 MB/s eta 0:00:05
#    ------------- -------------------------- 5.3/15.5 MB 2.5 MB/s eta 0:00:05
#    --------------- ------------------------ 5.9/15.5 MB 2.5 MB/s eta 0:00:04
#    --------------- ------------------------ 6.0/15.5 MB 2.5 MB/s eta 0:00:04
#    --------------- ------------------------ 6.2/15.5 MB 2.5 MB/s eta 0:00:04
#    ---------------- ----------------------- 6.3/15.5 MB 2.5 MB/s eta 0:00:04
#    ---------------- ----------------------- 6.4/15.5 MB 2.5 MB/s eta 0:00:04
#    ---------------- ----------------------- 6.5/15.5 MB 2.5 MB/s eta 0:00:04
#    ----------------- ---------------------- 6.6/15.5 MB 2.5 MB/s eta 0:00:04
#    ----------------- ---------------------- 6.7/15.5 MB 2.5 MB/s eta 0:00:04
#    ----------------- ---------------------- 6.8/15.5 MB 2.5 MB/s eta 0:00:04
#    ----------------- ---------------------- 6.9/15.5 MB 2.4 MB/s eta 0:00:04
#    ------------------ --------------------- 7.1/15.5 MB 2.5 MB/s eta 0:00:04
#    ------------------ --------------------- 7.2/15.5 MB 2.5 MB/s eta 0:00:04
#    ------------------ --------------------- 7.3/15.5 MB 2.4 MB/s eta 0:00:04
#    ------------------- -------------------- 7.4/15.5 MB 2.5 MB/s eta 0:00:04
#    ------------------- -------------------- 7.5/15.5 MB 2.5 MB/s eta 0:00:04
#    ------------------- -------------------- 7.6/15.5 MB 2.5 MB/s eta 0:00:04
#    ------------------- -------------------- 7.7/15.5 MB 2.4 MB/s eta 0:00:04
#    -------------------- ------------------- 7.9/15.5 MB 2.5 MB/s eta 0:00:04
#    -------------------- ------------------- 8.0/15.5 MB 2.4 MB/s eta 0:00:04
#    -------------------- ------------------- 8.1/15.5 MB 2.5 MB/s eta 0:00:04
#    --------------------- ------------------ 8.2/15.5 MB 2.4 MB/s eta 0:00:04
#    --------------------- ------------------ 8.3/15.5 MB 2.4 MB/s eta 0:00:03
#    --------------------- ------------------ 8.4/15.5 MB 2.5 MB/s eta 0:00:03
#    ---------------------- ----------------- 8.5/15.5 MB 2.4 MB/s eta 0:00:03
#    ---------------------- ----------------- 8.7/15.5 MB 2.4 MB/s eta 0:00:03
#    ---------------------- ----------------- 8.8/15.5 MB 2.5 MB/s eta 0:00:03
#    ---------------------- ----------------- 8.9/15.5 MB 2.5 MB/s eta 0:00:03
#    ----------------------- ---------------- 9.0/15.5 MB 2.5 MB/s eta 0:00:03
#    ----------------------- ---------------- 9.1/15.5 MB 2.5 MB/s eta 0:00:03
#    ----------------------- ---------------- 9.2/15.5 MB 2.5 MB/s eta 0:00:03
#    ------------------------ --------------- 9.3/15.5 MB 2.4 MB/s eta 0:00:03
#    ------------------------ --------------- 9.5/15.5 MB 2.4 MB/s eta 0:00:03
#    ------------------------ --------------- 9.6/15.5 MB 2.5 MB/s eta 0:00:03
#    ------------------------ --------------- 9.7/15.5 MB 2.5 MB/s eta 0:00:03
#    ------------------------- -------------- 9.8/15.5 MB 2.4 MB/s eta 0:00:03
#    ------------------------- -------------- 9.9/15.5 MB 2.4 MB/s eta 0:00:03
#    ------------------------- -------------- 10.0/15.5 MB 2.5 MB/s eta 0:00:03
#    -------------------------- ------------- 10.1/15.5 MB 2.4 MB/s eta 0:00:03
#    -------------------------- ------------- 10.3/15.5 MB 2.5 MB/s eta 0:00:03
#    -------------------------- ------------- 10.4/15.5 MB 2.4 MB/s eta 0:00:03
#    --------------------------- ------------ 10.5/15.5 MB 2.4 MB/s eta 0:00:03
#    --------------------------- ------------ 10.6/15.5 MB 2.4 MB/s eta 0:00:03
#    --------------------------- ------------ 10.7/15.5 MB 2.4 MB/s eta 0:00:02
#    --------------------------- ------------ 10.8/15.5 MB 2.4 MB/s eta 0:00:02
#    ---------------------------- ----------- 10.9/15.5 MB 2.5 MB/s eta 0:00:02
#    ---------------------------- ----------- 11.0/15.5 MB 2.4 MB/s eta 0:00:02
#    ---------------------------- ----------- 11.2/15.5 MB 2.4 MB/s eta 0:00:02
#    ----------------------------- ---------- 11.3/15.5 MB 2.4 MB/s eta 0:00:02
#    ----------------------------- ---------- 11.4/15.5 MB 2.4 MB/s eta 0:00:02
#    ----------------------------- ---------- 11.5/15.5 MB 2.4 MB/s eta 0:00:02
#    ----------------------------- ---------- 11.6/15.5 MB 2.4 MB/s eta 0:00:02
#    ------------------------------ --------- 11.7/15.5 MB 2.4 MB/s eta 0:00:02
#    ------------------------------ --------- 11.8/15.5 MB 2.4 MB/s eta 0:00:02
#    ------------------------------ --------- 12.0/15.5 MB 2.4 MB/s eta 0:00:02
#    ------------------------------- -------- 12.1/15.5 MB 2.5 MB/s eta 0:00:02
#    ------------------------------- -------- 12.2/15.5 MB 2.4 MB/s eta 0:00:02
#    ------------------------------- -------- 12.3/15.5 MB 2.4 MB/s eta 0:00:02
#    -------------------------------- ------- 12.4/15.5 MB 2.4 MB/s eta 0:00:02
#    -------------------------------- ------- 12.5/15.5 MB 2.4 MB/s eta 0:00:02
#    -------------------------------- ------- 12.6/15.5 MB 2.4 MB/s eta 0:00:02
#    -------------------------------- ------- 12.8/15.5 MB 2.4 MB/s eta 0:00:02
#    --------------------------------- ------ 12.9/15.5 MB 2.4 MB/s eta 0:00:02
#    --------------------------------- ------ 13.0/15.5 MB 2.4 MB/s eta 0:00:02
#    --------------------------------- ------ 13.1/15.5 MB 2.4 MB/s eta 0:00:01
#    ---------------------------------- ----- 13.2/15.5 MB 2.4 MB/s eta 0:00:01
#    ---------------------------------- ----- 13.3/15.5 MB 2.4 MB/s eta 0:00:01
#    ---------------------------------- ----- 13.4/15.5 MB 2.4 MB/s eta 0:00:01
#    ---------------------------------- ----- 13.5/15.5 MB 2.4 MB/s eta 0:00:01
#    ----------------------------------- ---- 13.7/15.5 MB 2.4 MB/s eta 0:00:01
#    ----------------------------------- ---- 13.8/15.5 MB 2.4 MB/s eta 0:00:01
#    ----------------------------------- ---- 13.9/15.5 MB 2.4 MB/s eta 0:00:01
#    ------------------------------------ --- 14.0/15.5 MB 2.4 MB/s eta 0:00:01
#    ------------------------------------ --- 14.1/15.5 MB 2.4 MB/s eta 0:00:01
#    ------------------------------------ --- 14.2/15.5 MB 2.4 MB/s eta 0:00:01
#    ------------------------------------- -- 14.4/15.5 MB 2.4 MB/s eta 0:00:01
#    ------------------------------------- -- 14.5/15.5 MB 2.4 MB/s eta 0:00:01
#    ------------------------------------- -- 14.6/15.5 MB 2.4 MB/s eta 0:00:01
#    ------------------------------------- -- 14.7/15.5 MB 2.4 MB/s eta 0:00:01
#    -------------------------------------- - 14.8/15.5 MB 2.4 MB/s eta 0:00:01
#    -------------------------------------- - 14.9/15.5 MB 2.4 MB/s eta 0:00:01
#    -------------------------------------- - 15.0/15.5 MB 2.4 MB/s eta 0:00:01
#    ---------------------------------------  15.2/15.5 MB 2.4 MB/s eta 0:00:01
#    ---------------------------------------  15.3/15.5 MB 2.4 MB/s eta 0:00:01
#    ---------------------------------------  15.4/15.5 MB 2.4 MB/s eta 0:00:01
#    ---------------------------------------  15.5/15.5 MB 2.4 MB/s eta 0:00:01
#    ---------------------------------------  15.5/15.5 MB 2.4 MB/s eta 0:00:01
#    ---------------------------------------  15.5/15.5 MB 2.4 MB/s eta 0:00:01
#    ---------------------------------------- 15.5/15.5 MB 2.4 MB/s eta 0:00:00
# Downloading pytz-2024.1-py2.py3-none-any.whl (505 kB)
#    ---------------------------------------- 0.0/505.5 kB ? eta -:--:--
#    --------- ------------------------------ 122.9/505.5 kB 2.4 MB/s eta 0:00:01
#    --------------------- ------------------ 276.5/505.5 kB 2.8 MB/s eta 0:00:01
#    ------------------------------ --------- 389.1/505.5 kB 3.0 MB/s eta 0:00:01
#    ---------------------------------------  501.8/505.5 kB 2.9 MB/s eta 0:00:01
#    ---------------------------------------- 505.5/505.5 kB 2.6 MB/s eta 0:00:00
# Downloading tzdata-2024.1-py2.py3-none-any.whl (345 kB)
#    ---------------------------------------- 0.0/345.4 kB ? eta -:--:--
#    ------------------ --------------------- 163.8/345.4 kB 3.3 MB/s eta 0:00:01
#    -------------------------------- ------- 276.5/345.4 kB 2.8 MB/s eta 0:00:01
#    ---------------------------------------- 345.4/345.4 kB 2.7 MB/s eta 0:00:00
# Installing collected packages: pytz, tzdata, numpy, pandas
# Successfully installed numpy-1.26.4 pandas-2.2.1 pytz-2024.1 tzdata-2024.1

# %%
! conda install lxml -y
# Out:
# Collecting package metadata (current_repodata.json): ...working... done
# Solving environment: ...working... done
#
# ## Package Plan ##
#
#   environment location: C:\Users\user\anaconda3\envs\pythonPracticeStatic12
#
#   added / updated specs:
#     - lxml
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     libxml2-2.10.4             |       h0ad7f3c_1         2.8 MB
#     libxslt-1.1.37             |       h2bbff1b_1         447 KB
#     lxml-4.9.3                 |  py312h09808a7_0         1.0 MB
#     ------------------------------------------------------------
#                                            Total:         4.3 MB
#
# The following NEW packages will be INSTALLED:
#
#   libiconv           pkgs/main/win-64::libiconv-1.16-h2bbff1b_2
#   libxml2            pkgs/main/win-64::libxml2-2.10.4-h0ad7f3c_1
#   libxslt            pkgs/main/win-64::libxslt-1.1.37-h2bbff1b_1
#   lxml               pkgs/main/win-64::lxml-4.9.3-py312h09808a7_0
#
# The following packages will be SUPERSEDED by a higher-priority channel:
#
#   ca-certificates    conda-forge::ca-certificates-2024.2.2~ --> pkgs/main::ca-certificates-2023.12.12-haa95532_0
#
#
#
# Downloading and Extracting Packages
#
# libxslt-1.1.37       | 447 KB    |            |   0%
#
# libxml2-2.10.4       | 2.8 MB    |            |   0%
#
#
# lxml-4.9.3           | 1.0 MB    |            |   0%
#
# libxml2-2.10.4       | 2.8 MB    |            |   1%
#
#
# lxml-4.9.3           | 1.0 MB    | 1          |   2%
#
# libxml2-2.10.4       | 2.8 MB    | 4          |   4%
# libxslt-1.1.37       | 447 KB    | 3          |   4%
#
# libxml2-2.10.4       | 2.8 MB    | 8          |   8%
#
#
# lxml-4.9.3           | 1.0 MB    | 4          |   5%
#
# libxml2-2.10.4       | 2.8 MB    | #4         |  15%
#
#
# lxml-4.9.3           | 1.0 MB    | #          |  11%
# libxslt-1.1.37       | 447 KB    | ##8        |  29%
#
# libxml2-2.10.4       | 2.8 MB    | #8         |  19%
#
#
# lxml-4.9.3           | 1.0 MB    | #5         |  16%
#
# libxml2-2.10.4       | 2.8 MB    | ##5        |  26%
#
#
# lxml-4.9.3           | 1.0 MB    | ##         |  20%
#
# libxml2-2.10.4       | 2.8 MB    | ###3       |  33%
# libxslt-1.1.37       | 447 KB    | #####7     |  57%
#
#
# lxml-4.9.3           | 1.0 MB    | ##4        |  25%
# libxslt-1.1.37       | 447 KB    | ########2  |  82%
#
# libxml2-2.10.4       | 2.8 MB    | ###8       |  39%
#
#
# lxml-4.9.3           | 1.0 MB    | ##9        |  30%
#
# libxml2-2.10.4       | 2.8 MB    | #####5     |  55%
#
#
# lxml-4.9.3           | 1.0 MB    | ####9      |  50%
#
# libxml2-2.10.4       | 2.8 MB    | #######    |  70%
#
#
# lxml-4.9.3           | 1.0 MB    | ######3    |  64%
#
# libxml2-2.10.4       | 2.8 MB    | #######9   |  80%
# libxslt-1.1.37       | 447 KB    | #########3 |  93%
#
# libxml2-2.10.4       | 2.8 MB    | ########8  |  89%
#
#
# lxml-4.9.3           | 1.0 MB    | #######3   |  73%
# libxslt-1.1.37       | 447 KB    | ########## | 100%
# libxslt-1.1.37       | 447 KB    | ########## | 100%
#
#
# lxml-4.9.3           | 1.0 MB    | #########6 |  97%
#
# libxml2-2.10.4       | 2.8 MB    | ########## | 100%
#
# libxml2-2.10.4       | 2.8 MB    | ########## | 100%
#
#
# lxml-4.9.3           | 1.0 MB    | ########## | 100%
#
#
#
#
#
#
#
#
# Preparing transaction: ...working... done
# Verifying transaction: ...working... done
# Executing transaction: ...working... done
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): repo.anaconda.com:443
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): repo.anaconda.com:443
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): repo.anaconda.com:443
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): repo.anaconda.com:443
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): repo.anaconda.com:443
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): repo.anaconda.com:443
# DEBUG:urllib3.connectionpool:https://repo.anaconda.com:443 "GET /pkgs/r/noarch/current_repodata.json HTTP/1.1" 304 0
# DEBUG:urllib3.connectionpool:https://repo.anaconda.com:443 "GET /pkgs/main/win-64/current_repodata.json HTTP/1.1" 304 0
# DEBUG:urllib3.connectionpool:https://repo.anaconda.com:443 "GET /pkgs/msys2/noarch/current_repodata.json HTTP/1.1" 304 0
# DEBUG:urllib3.connectionpool:https://repo.anaconda.com:443 "GET /pkgs/main/noarch/current_repodata.json HTTP/1.1" 304 0
# DEBUG:urllib3.connectionpool:https://repo.anaconda.com:443 "GET /pkgs/r/win-64/current_repodata.json HTTP/1.1" 304 0
# DEBUG:urllib3.connectionpool:https://repo.anaconda.com:443 "GET /pkgs/msys2/win-64/current_repodata.json HTTP/1.1" 304 0
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 23.7.2
#   latest version: 24.1.2
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda
#
# Or to minimize the number of packages updated during conda update use
#
#      conda install conda=24.1.2
#
#
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): repo.anaconda.com:443
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): repo.anaconda.com:443
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): repo.anaconda.com:443
# DEBUG:urllib3.connectionpool:https://repo.anaconda.com:443 "GET /pkgs/main/win-64/libxml2-2.10.4-h0ad7f3c_1.conda HTTP/1.1" 200 2976881
# DEBUG:urllib3.connectionpool:https://repo.anaconda.com:443 "GET /pkgs/main/win-64/lxml-4.9.3-py312h09808a7_0.conda HTTP/1.1" 200 1052552
# DEBUG:urllib3.connectionpool:https://repo.anaconda.com:443 "GET /pkgs/main/win-64/libxslt-1.1.37-h2bbff1b_1.conda HTTP/1.1" 200 457852

# %%
import pandas as pd 

table = pd.read_html('https://www.w3schools.com/python/gloss_python_arithmetic_operators.asp')

table[0]
# Out:
#   Operator            Name Example    Try it
# 0        +        Addition   x + y  Try it »
# 1        -     Subtraction   x - y  Try it »
# 2        *  Multiplication   x * y  Try it »
# 3        /        Division   x / y  Try it »
# 4        %         Modulus   x % y  Try it »
# 5       **  Exponentiation  x ** y  Try it »
# 6       //  Floor division  x // y  Try it »

# %%
4.3 * 2
# Out:
# 8.6

# %%
14.8 // 3
# Out:
# 4.0

# %%
2/2

# DATA TYPE CHANGED TO FLOAT
# Out:
# 1.0

# %%
12/3
# Out:
# 4.0

# %%
4/3
# Out:
# 1.3333333333333333

# %%
4 // 3
# Out:
# 1

# %%
2 ** 3
# Out:
# 8

# %% [markdown]
# # Assignment Operator

# %% [markdown]
# - =
# - += and similar

# %%
a: int =3
a += 2
print(a)
# Out:
# 5

# %% [markdown]
# # Comparison Operator

# %% [markdown]
# - ans is boolean
# - == , != , > , < , >=, <=,
# - comparison with respect to ascii values

# %%
w : str = "A"
n :str = "a"

w > n
# Out:
# False

# %% [markdown]
# - How false ?
# - on the basis of ASCII values
# - Explained below

# %%
# From value to ASCII code?
print(ord(w)) # ASCII values 65
print(ord(n)) # ASCII values 97


# From ASCII code to value?
print(chr(65))
# Out:
# 65
# 97
# A

# %% [markdown]
# # Logical Operators
#
# - and
# - or
# - not

# %%
print( 1 < 2 and 3>5 and 2<1)
# Out:
# False

# %%
not (1 > 2)
# Out:
# True

# %% [markdown]
# # Operators
#
# - is
# - is not

# %%
person_one : str = 'Wasam'
person_sitting_at_the_top : str = "Wasam"

print(id(person_one))
print(id(person_sitting_at_the_top))
# Out:
# 2448065896896
# 2448065896896

# %%
person_one is person_sitting_at_the_top
# also known as shallow copy bcz of same physical address
# True bcz address are same
# Out:
# True

# %%
person_one is not person_sitting_at_the_top
# Out:
# False

# %% [markdown]
# - == , != value level comparison
# - is , is not Memory level comparison
